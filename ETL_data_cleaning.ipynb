# %%
import pandas as pd
import datetime as dt
import pymongo
import pprint
from sqlalchemy import create_engine

# %% [markdown]
# ### Extract CSVs into DataFrames

# %%
HuffPost_csv = "HuffPost_trump_approval.csv"

# %%
FiveThirtyEight_csv = "FiveThirtyEight_president_approval_polls.csv"

# %% [markdown]
# ### Transform HuffPost DataFrame

# %%
HuffPost = pd.read_csv(HuffPost_csv)

HuffPost.head()
# Out:
#   survey_organization party_affiliation  start_date    end_date survey_method  \
# 0              Gallup              None  2017-01-20  2017-01-22    Live Phone
# 1       Ipsos/Reuters              None  2017-01-20  2017-01-24      Internet
# 2       Ipsos/Reuters              None  2017-01-20  2017-01-24      Internet
# 3       Ipsos/Reuters              None  2017-01-20  2017-01-24      Internet
# 4       Ipsos/Reuters              None  2017-01-20  2017-01-24      Internet
#
#                                      survey_question      survey_population  \
# 0                                                NaN                 Adults
# 1  Overall, do you approve or disapprove about th...                 Adults
# 2  Overall, do you approve or disapprove about th...     Adults (Democrats)
# 3  Overall, do you approve or disapprove about th...   Adults (Republicans)
# 4  Overall, do you approve or disapprove about th...  Adults (Independents)
#
#    survey_sample  approve_percent  disapprove_percent  undecided_percent  \
# 0         1500.0               45                  45                NaN
# 1         1633.0               43                  45               13.0
# 2          680.0               15                  75               10.0
# 3          557.0               85                  11                4.0
# 4          228.0               38                  39               23.0
#
#    margin_of_error
# 0              3.0
# 1              2.8
# 2              4.3
# 3              4.7
# 4              7.4

# %% [markdown]
# ### Transform FiveThirtyEight DataFrame

# %%
FiveThirtyEight = pd.read_csv(FiveThirtyEight_csv)
FiveThirtyEight.head()
# Rename ID column for Mongo load
# counties.rename(columns = { "ID" : "_id"} , inplace = True)
# counties.head()
# Out:
#    question_id  poll_id   cycle  state    politician  pollster_id  \
# 0       119718    64736  2020.0    NaN  Donald Trump          568
# 1       119719    64736  2020.0    NaN  Donald Trump          568
# 2       119705    64731  2020.0    NaN  Donald Trump          568
# 3       119706    64731  2020.0    NaN  Donald Trump          568
# 4       119717    64735  2020.0    NaN  Donald Trump          399
#
#                                    pollster sponsor_ids sponsors  \
# 0                                    YouGov         NaN      NaN
# 1                                    YouGov         NaN      NaN
# 2                                    YouGov         NaN      NaN
# 3                                    YouGov         NaN      NaN
# 4  Rasmussen Reports/Pulse Opinion Research         NaN      NaN
#
#                                display_name  ...  start_date end_date  \
# 0                                    YouGov  ...      3/4/20   3/6/20
# 1                                    YouGov  ...      3/4/20   3/6/20
# 2                                    YouGov  ...      3/3/20   3/5/20
# 3                                    YouGov  ...      3/3/20   3/5/20
# 4  Rasmussen Reports/Pulse Opinion Research  ...      3/3/20   3/5/20
#
#   sponsor_candidate  tracking    created_at notes  \
# 0               NaN       NaN  3/6/20 11:35   NaN
# 1               NaN       NaN  3/6/20 11:35   NaN
# 2               NaN       NaN  3/5/20 15:54   NaN
# 3               NaN       NaN  3/5/20 15:54   NaN
# 4               NaN      True  3/6/20 09:28   NaN
#
#                                                  url source   yes    no
# 0  https://docs.cdn.yougov.com/dojx4dgn4g/tabs_Tr...    538  41.0  51.0
# 1  https://docs.cdn.yougov.com/dojx4dgn4g/tabs_Tr...    538  44.0  55.0
# 2  https://docs.cdn.yougov.com/5e41wsj1pi/tabs_Tr...    538  43.0  50.0
# 3  https://docs.cdn.yougov.com/5e41wsj1pi/tabs_Tr...    538  45.0  53.0
# 4  http://www.rasmussenreports.com/public_content...    538  47.0  51.0
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Reorganize Columns for Homogeneity

# %%
sorted(list(HuffPost["survey_organization"].unique()))
# Out:
# ['ARG',
#  'CBS',
#  'CNN',
#  'FOX',
#  'Gallup',
#  'HuffPost/YouGov',
#  'IBD/TIPP',
#  'Ipsos/Reuters',
#  'McClatchy/Marist',
#  'NBC/SurveyMonkey',
#  'NBC/WSJ',
#  'PPP (D)',
#  'Pew',
#  'Politico/Morning Consult',
#  'Quinnipiac',
#  'Rasmussen',
#  'SurveyMonkey',
#  'YouGov/Economist',
#  'Zogby']

# %%
sorted(list(FiveThirtyEight["pollster"].unique()))
# Out:
# ['ABC News/Washington Post',
#  'AP-NORC',
#  'America First Policies',
#  'American Research Group',
#  'AtlasIntel',
#  'Basswood Research',
#  'CBS News/New York Times',
#  'CNN/Opinion Research Corp.',
#  'Cards Against Humanity/Survey Sampling International',
#  'Civiqs',
#  'Civis Analytics',
#  'Climate Nexus',
#  'Cygnal',
#  'D-CYFOR',
#  'Emerson College',
#  'Fox News/Beacon Research/Shaw & Co. Research',
#  'GBAO',
#  'GQR Research (GQRR)',
#  'Gallup',
#  'Garin-Hart-Yang Research Group',
#  'Garin-Hart-Yang/Global Strategy Group',
#  'Georgetown University (Battleground)',
#  'Global Strategy Group/GBA Strategies',
#  'Gravis Marketing',
#  'Harris Insights & Analytics',
#  'Heart+Mind Strategies',
#  'IBD/TIPP',
#  'Ipsos',
#  'Kaiser Family Foundation',
#  'Lucid',
#  'Marist College',
#  'Marquette University Law School',
#  'McLaughlin & Associates',
#  'Monmouth University',
#  'Morning Consult',
#  'NBC News/Wall Street Journal',
#  'Opinion Savvy/InsiderAdvantage',
#  'PSB Research',
#  'Pew Research Center',
#  'Public Opinion Strategies',
#  'Public Policy Polling',
#  'Public Religion Research Institute',
#  'Quinnipiac University',
#  'Rasmussen Reports/Pulse Opinion Research',
#  'Research Co.',
#  'SSRS',
#  'Saint Leo University',
#  'Selzer & Co.',
#  'SocialSphere',
#  'Suffolk University',
#  'SurveyMonkey',
#  'SurveyUSA',
#  'Tarrance Group',
#  'USC Dornsife/LA Times',
#  'Vox Populi Polling',
#  'Washington Post/Kaiser Family Foundation',
#  'YouGov',
#  'YouGov Blue',
#  'YouGov Blue/Data for Progress',
#  'Zogby Interactive/JZ Analytics',
#  'icitizen']

# %%
# Create a Huff Post to FiveThirtyEight naming dictionary for overlapping organizations
huff_538_name_dict = {
    "ARG": "American Research Group",
    "CNN": "CNN/Opinion Research Corp.",
    "FOX": "Fox News/Beacon Research/Shaw & Co. Research",
    "Gallup": "Gallup",
    "IBD/TIPP": "IBD/TIPP",
    "Ipsos/Reuters": "Ipsos",
    "NBC/WSJ": "NBC News/Wall Street Journal",
    "Public Policy Polling": "PPP (D)",
    "Pew": "Pew Research Center",
    "Quinnipiac": "Quinnipiac University",
    "Rasmussen": "Rasmussen Reports/Pulse Opinion Research",
    "SurveyMonkey": "SurveyMonkey",
    "YouGov/Economist": "YouGov",
    "Zogby": "Zogby Interactive/JZ Analytics"    
}

# %%
# Rename organizations in the Huff Post data frame to match organization names in the 538 data frame.
HuffPost.replace(huff_538_name_dict, inplace=True)
HuffPost.head()
# Out:
#   survey_organization party_affiliation  start_date    end_date survey_method  \
# 0              Gallup              None  2017-01-20  2017-01-22    Live Phone
# 1               Ipsos              None  2017-01-20  2017-01-24      Internet
# 2               Ipsos              None  2017-01-20  2017-01-24      Internet
# 3               Ipsos              None  2017-01-20  2017-01-24      Internet
# 4               Ipsos              None  2017-01-20  2017-01-24      Internet
#
#                                      survey_question      survey_population  \
# 0                                                NaN                 Adults
# 1  Overall, do you approve or disapprove about th...                 Adults
# 2  Overall, do you approve or disapprove about th...     Adults (Democrats)
# 3  Overall, do you approve or disapprove about th...   Adults (Republicans)
# 4  Overall, do you approve or disapprove about th...  Adults (Independents)
#
#    survey_sample  approve_percent  disapprove_percent  undecided_percent  \
# 0         1500.0               45                  45                NaN
# 1         1633.0               43                  45               13.0
# 2          680.0               15                  75               10.0
# 3          557.0               85                  11                4.0
# 4          228.0               38                  39               23.0
#
#    margin_of_error
# 0              3.0
# 1              2.8
# 2              4.3
# 3              4.7
# 4              7.4

# %%
# Create a dictionary to expand the abbreviations used by 538 for population to more closely match those used by Huff Post
_538_huff_pop_dict = {
    "a": "Adults",
    "rv": "Registered Voters",
    "v": "Voters",
    "lv": "Likely Voters"
}

# %%
# Rename populations in the 538 data frame to more closely match those in the Huff Post data frame
FiveThirtyEight.replace(_538_huff_pop_dict, inplace=True)
FiveThirtyEight['population'].unique()
# Out:
# array(['Adults', 'Registered Voters', 'Likely Voters', 'Voters'],
#       dtype=object)

# %%
# Create trimmed 538 data frame
_538_trimmed = FiveThirtyEight[["pollster",
                               "sample_size",
                               "population",
                               "methodology",
                               "start_date",
                               "end_date",
                               "yes",
                               "no"
                               ]
                              ]
_538_trimmed.head()
# Out:
#                                    pollster  sample_size         population  \
# 0                                    YouGov         1000             Adults
# 1                                    YouGov          755  Registered Voters
# 2                                    YouGov         1000             Adults
# 3                                    YouGov          763  Registered Voters
# 4  Rasmussen Reports/Pulse Opinion Research         1500      Likely Voters
#
#   methodology start_date end_date   yes    no
# 0      Online     3/4/20   3/6/20  41.0  51.0
# 1      Online     3/4/20   3/6/20  44.0  55.0
# 2      Online     3/3/20   3/5/20  43.0  50.0
# 3      Online     3/3/20   3/5/20  45.0  53.0
# 4  IVR/Online     3/3/20   3/5/20  47.0  51.0

# %%
# Convert start date and end date into datetime objects
_538_trimmed["start_date"] = pd.to_datetime(_538_trimmed["start_date"])
_538_trimmed["end_date"] = pd.to_datetime(_538_trimmed["end_date"])
_538_trimmed.head()
# Out:
# C:\Users\Tristan\anaconda\Anaconda3\envs\pythondata\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Tristan\anaconda\Anaconda3\envs\pythondata\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                    pollster  sample_size         population  \
# 0                                    YouGov         1000             Adults
# 1                                    YouGov          755  Registered Voters
# 2                                    YouGov         1000             Adults
# 3                                    YouGov          763  Registered Voters
# 4  Rasmussen Reports/Pulse Opinion Research         1500      Likely Voters
#
#   methodology start_date   end_date   yes    no
# 0      Online 2020-03-04 2020-03-06  41.0  51.0
# 1      Online 2020-03-04 2020-03-06  44.0  55.0
# 2      Online 2020-03-03 2020-03-05  43.0  50.0
# 3      Online 2020-03-03 2020-03-05  45.0  53.0
# 4  IVR/Online 2020-03-03 2020-03-05  47.0  51.0

# %%
# Create trimmed Huff Post data frame
huff_post_trimmed = HuffPost[["survey_organization",
                              "start_date",
                              "end_date",
                              "survey_method",
                              "survey_population",
                              "survey_sample",
                              "approve_percent",
                              "disapprove_percent",
                              "undecided_percent",
                              "margin_of_error"
                             ]
                            ]
huff_post_trimmed.head()
# Out:
#   survey_organization  start_date    end_date survey_method  \
# 0              Gallup  2017-01-20  2017-01-22    Live Phone
# 1               Ipsos  2017-01-20  2017-01-24      Internet
# 2               Ipsos  2017-01-20  2017-01-24      Internet
# 3               Ipsos  2017-01-20  2017-01-24      Internet
# 4               Ipsos  2017-01-20  2017-01-24      Internet
#
#        survey_population  survey_sample  approve_percent  disapprove_percent  \
# 0                 Adults         1500.0               45                  45
# 1                 Adults         1633.0               43                  45
# 2     Adults (Democrats)          680.0               15                  75
# 3   Adults (Republicans)          557.0               85                  11
# 4  Adults (Independents)          228.0               38                  39
#
#    undecided_percent  margin_of_error
# 0                NaN              3.0
# 1               13.0              2.8
# 2               10.0              4.3
# 3                4.0              4.7
# 4               23.0              7.4

# %%
# Convert start date and end date into datetime objects
huff_post_trimmed["start_date"] = pd.to_datetime(huff_post_trimmed["start_date"], yearfirst=True)
huff_post_trimmed["end_date"] = pd.to_datetime(huff_post_trimmed["end_date"], yearfirst=True)
huff_post_trimmed.head()
# Out:
# C:\Users\Tristan\anaconda\Anaconda3\envs\pythondata\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Tristan\anaconda\Anaconda3\envs\pythondata\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#   survey_organization start_date   end_date survey_method  \
# 0              Gallup 2017-01-20 2017-01-22    Live Phone
# 1               Ipsos 2017-01-20 2017-01-24      Internet
# 2               Ipsos 2017-01-20 2017-01-24      Internet
# 3               Ipsos 2017-01-20 2017-01-24      Internet
# 4               Ipsos 2017-01-20 2017-01-24      Internet
#
#        survey_population  survey_sample  approve_percent  disapprove_percent  \
# 0                 Adults         1500.0               45                  45
# 1                 Adults         1633.0               43                  45
# 2     Adults (Democrats)          680.0               15                  75
# 3   Adults (Republicans)          557.0               85                  11
# 4  Adults (Independents)          228.0               38                  39
#
#    undecided_percent  margin_of_error
# 0                NaN              3.0
# 1               13.0              2.8
# 2               10.0              4.3
# 3                4.0              4.7
# 4               23.0              7.4

# %%
# Create a column name mapper for homogeneity
_538_to_huff_columns = {
    "pollster": "survey_organization",
    "methodology": "survey_method",
    "population": "survey_population",
    "sample_size": "survey_sample",
    "yes": "approve_percent",
    "no": "disapprove_percent"
}

# %%
# Rename columns in the trimmed 538 data frame
_538_trimmed.rename(columns=_538_to_huff_columns, inplace=True)
_538_trimmed.head()
# Out:
# C:\Users\Tristan\anaconda\Anaconda3\envs\pythondata\lib\site-packages\pandas\core\frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                         survey_organization  survey_sample  survey_population  \
# 0                                    YouGov           1000             Adults
# 1                                    YouGov            755  Registered Voters
# 2                                    YouGov           1000             Adults
# 3                                    YouGov            763  Registered Voters
# 4  Rasmussen Reports/Pulse Opinion Research           1500      Likely Voters
#
#   survey_method start_date   end_date  approve_percent  disapprove_percent
# 0        Online 2020-03-04 2020-03-06             41.0                51.0
# 1        Online 2020-03-04 2020-03-06             44.0                55.0
# 2        Online 2020-03-03 2020-03-05             43.0                50.0
# 3        Online 2020-03-03 2020-03-05             45.0                53.0
# 4    IVR/Online 2020-03-03 2020-03-05             47.0                51.0

# %%
# Merge the two dataframes
merged_df = _538_trimmed.merge(huff_post_trimmed,
                               how="outer",
                               on=["survey_organization",
                                   "survey_sample",
                                   "survey_population",
                                   "survey_method",
                                   "start_date",
                                   "end_date",
                                   "approve_percent",
                                   "disapprove_percent"
                                  ]
                              )
merged_df.head()
# Out:
# C:\Users\Tristan\anaconda\Anaconda3\envs\pythondata\lib\site-packages\pandas\core\reshape\merge.py:1097: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation
#   UserWarning,
#                         survey_organization  survey_sample  survey_population  \
# 0                                    YouGov         1000.0             Adults
# 1                                    YouGov          755.0  Registered Voters
# 2                                    YouGov         1000.0             Adults
# 3                                    YouGov          763.0  Registered Voters
# 4  Rasmussen Reports/Pulse Opinion Research         1500.0      Likely Voters
#
#   survey_method start_date   end_date  approve_percent  disapprove_percent  \
# 0        Online 2020-03-04 2020-03-06             41.0                51.0
# 1        Online 2020-03-04 2020-03-06             44.0                55.0
# 2        Online 2020-03-03 2020-03-05             43.0                50.0
# 3        Online 2020-03-03 2020-03-05             45.0                53.0
# 4    IVR/Online 2020-03-03 2020-03-05             47.0                51.0
#
#    undecided_percent  margin_of_error
# 0                NaN              NaN
# 1                NaN              NaN
# 2                NaN              NaN
# 3                NaN              NaN
# 4                NaN              NaN

# %%
# Homogenize the survey methods
# merged_df["survey_method"].unique()
survey_homogenizer = {
    "Internet": "Online",
    "Live Phone / Online": "Live Phone/Online",
    "Automated Phone/Internet": "Automated Phone/Online"
}
merged_df.replace(survey_homogenizer, inplace=True)

# Check the renaming behaved as expected
merged_df["survey_method"].unique()
# Out:
# array(['Online', 'IVR/Online', 'Automated Phone', 'Live Phone',
#        'Live Phone/Online', nan, 'IVR', 'Live PHone',
#        'Automated Phone/Online'], dtype=object)

# %% [markdown]
# ### Create database connection

# %%
# create mongo connection
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

db = client.approval

# Remove existing data
db.approval_polls.drop()

# %% [markdown]
# Load DataFrames in database:

# %%
# insert data into respective collections

db.approval_polls.insert_many(merged_df.to_dict( orient = 'records'))

# %%
# query database test
approval_polls = db.approval_polls.find()
for poll in approval_polls:
    print(poll)
# Out:
# {'_id': ObjectId('5e67092800adebab1464fb38'), 'survey_organization': 'YouGov', 'survey_sample': 1000.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 3, 4, 0, 0), 'end_date': datetime.datetime(2020, 3, 6, 0, 0), 'approve_percent': 41.0, 'disapprove_percent': 51.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb39'), 'survey_organization': 'YouGov', 'survey_sample': 755.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 3, 4, 0, 0), 'end_date': datetime.datetime(2020, 3, 6, 0, 0), 'approve_percent': 44.0, 'disapprove_percent': 55.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb3a'), 'survey_organization': 'YouGov', 'survey_sample': 1000.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 3, 3, 0, 0), 'end_date': datetime.datetime(2020, 3, 5, 0, 0), 'approve_percent': 43.0, 'disapprove_percent': 50.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb3b'), 'survey_organization': 'YouGov', 'survey_sample': 763.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 3, 3, 0, 0), 'end_date': datetime.datetime(2020, 3, 5, 0, 0), 'approve_percent': 45.0, 'disapprove_percent': 53.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb3c'), 'survey_organization': 'Rasmussen Reports/Pulse Opinion Research', 'survey_sample': 1500.0, 'survey_population': 'Likely Voters', 'survey_method': 'IVR/Online', 'start_date': datetime.datetime(2020, 3, 3, 0, 0), 'end_date': datetime.datetime(2020, 3, 5, 0, 0), 'approve_percent': 47.0, 'disapprove_percent': 51.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb3d'), 'survey_organization': 'Morning Consult', 'survey_sample': 1990.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 3, 3, 0, 0), 'end_date': datetime.datetime(2020, 3, 5, 0, 0), 'approve_percent': 45.0, 'disapprove_percent': 52.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb3e'), 'survey_organization': 'Morning Consult', 'survey_sample': 1990.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 3, 4, 0, 0), 'end_date': datetime.datetime(2020, 3, 4, 0, 0), 'approve_percent': 41.0, 'disapprove_percent': 57.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb3f'), 'survey_organization': 'Rasmussen Reports/Pulse Opinion Research', 'survey_sample': 1500.0, 'survey_population': 'Likely Voters', 'survey_method': 'IVR/Online', 'start_date': datetime.datetime(2020, 3, 2, 0, 0), 'end_date': datetime.datetime(2020, 3, 4, 0, 0), 'approve_percent': 48.0, 'disapprove_percent': 50.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb40'), 'survey_organization': 'YouGov', 'survey_sample': 1000.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 3, 2, 0, 0), 'end_date': datetime.datetime(2020, 3, 4, 0, 0), 'approve_percent': 43.0, 'disapprove_percent': 51.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb41'), 'survey_organization': 'YouGov', 'survey_sample': 750.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 3, 2, 0, 0), 'end_date': datetime.datetime(2020, 3, 4, 0, 0), 'approve_percent': 45.0, 'disapprove_percent': 53.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb42'), 'survey_organization': 'Ipsos', 'survey_sample': 1115.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 3, 2, 0, 0), 'end_date': datetime.datetime(2020, 3, 3, 0, 0), 'approve_percent': 42.0, 'disapprove_percent': 53.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb43'), 'survey_organization': 'Ipsos', 'survey_sample': 943.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 3, 2, 0, 0), 'end_date': datetime.datetime(2020, 3, 3, 0, 0), 'approve_percent': 44.0, 'disapprove_percent': 54.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb44'), 'survey_organization': 'Public Policy Polling', 'survey_sample': 866.0, 'survey_population': 'Registered Voters', 'survey_method': 'Automated Phone', 'start_date': datetime.datetime(2020, 3, 2, 0, 0), 'end_date': datetime.datetime(2020, 3, 3, 0, 0), 'approve_percent': 41.0, 'disapprove_percent': 55.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb45'), 'survey_organization': 'Rasmussen Reports/Pulse Opinion Research', 'survey_sample': 1500.0, 'survey_population': 'Likely Voters', 'survey_method': 'IVR/Online', 'start_date': datetime.datetime(2020, 3, 1, 0, 0), 'end_date': datetime.datetime(2020, 3, 3, 0, 0), 'approve_percent': 48.0, 'disapprove_percent': 49.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb46'), 'survey_organization': 'YouGov', 'survey_sample': 1500.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 3, 1, 0, 0), 'end_date': datetime.datetime(2020, 3, 3, 0, 0), 'approve_percent': 41.0, 'disapprove_percent': 48.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb47'), 'survey_organization': 'YouGov', 'survey_sample': 1134.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 3, 1, 0, 0), 'end_date': datetime.datetime(2020, 3, 3, 0, 0), 'approve_percent': 44.0, 'disapprove_percent': 53.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb48'), 'survey_organization': 'YouGov', 'survey_sample': 1000.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 3, 1, 0, 0), 'end_date': datetime.datetime(2020, 3, 3, 0, 0), 'approve_percent': 41.0, 'disapprove_percent': 51.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb49'), 'survey_organization': 'YouGov', 'survey_sample': 732.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 3, 1, 0, 0), 'end_date': datetime.datetime(2020, 3, 3, 0, 0), 'approve_percent': 43.0, 'disapprove_percent': 54.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb4a'), 'survey_organization': 'YouGov', 'survey_sample': 1000.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 29, 0, 0), 'end_date': datetime.datetime(2020, 3, 3, 0, 0), 'approve_percent': 43.0, 'disapprove_percent': 51.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb4b'), 'survey_organization': 'YouGov', 'survey_sample': 790.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 29, 0, 0), 'end_date': datetime.datetime(2020, 3, 3, 0, 0), 'approve_percent': 45.0, 'disapprove_percent': 53.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb4c'), 'survey_organization': 'Rasmussen Reports/Pulse Opinion Research', 'survey_sample': 1500.0, 'survey_population': 'Likely Voters', 'survey_method': 'IVR/Online', 'start_date': datetime.datetime(2020, 2, 27, 0, 0), 'end_date': datetime.datetime(2020, 3, 2, 0, 0), 'approve_percent': 47.0, 'disapprove_percent': 51.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb4d'), 'survey_organization': 'Morning Consult', 'survey_sample': 1995.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 3, 1, 0, 0), 'end_date': datetime.datetime(2020, 3, 1, 0, 0), 'approve_percent': 42.0, 'disapprove_percent': 56.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb4e'), 'survey_organization': 'Morning Consult', 'survey_sample': 2200.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 28, 0, 0), 'end_date': datetime.datetime(2020, 3, 1, 0, 0), 'approve_percent': 43.0, 'disapprove_percent': 52.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb4f'), 'survey_organization': 'Morning Consult', 'survey_sample': 2201.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 28, 0, 0), 'end_date': datetime.datetime(2020, 3, 1, 0, 0), 'approve_percent': 43.0, 'disapprove_percent': 52.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb50'), 'survey_organization': 'Morning Consult', 'survey_sample': 1997.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 28, 0, 0), 'end_date': datetime.datetime(2020, 3, 1, 0, 0), 'approve_percent': 44.0, 'disapprove_percent': 54.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb51'), 'survey_organization': 'Morning Consult', 'survey_sample': 1992.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 28, 0, 0), 'end_date': datetime.datetime(2020, 3, 1, 0, 0), 'approve_percent': 44.0, 'disapprove_percent': 53.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb52'), 'survey_organization': 'YouGov', 'survey_sample': 1000.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 28, 0, 0), 'end_date': datetime.datetime(2020, 3, 1, 0, 0), 'approve_percent': 38.0, 'disapprove_percent': 53.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb53'), 'survey_organization': 'YouGov', 'survey_sample': 769.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 28, 0, 0), 'end_date': datetime.datetime(2020, 3, 1, 0, 0), 'approve_percent': 43.0, 'disapprove_percent': 56.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb54'), 'survey_organization': 'Morning Consult', 'survey_sample': 2200.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 27, 0, 0), 'end_date': datetime.datetime(2020, 3, 1, 0, 0), 'approve_percent': 43.0, 'disapprove_percent': 52.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb55'), 'survey_organization': 'Rasmussen Reports/Pulse Opinion Research', 'survey_sample': 1500.0, 'survey_population': 'Likely Voters', 'survey_method': 'IVR/Online', 'start_date': datetime.datetime(2020, 2, 26, 0, 0), 'end_date': datetime.datetime(2020, 3, 1, 0, 0), 'approve_percent': 46.0, 'disapprove_percent': 52.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb56'), 'survey_organization': 'YouGov', 'survey_sample': 1000.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 27, 0, 0), 'end_date': datetime.datetime(2020, 2, 29, 0, 0), 'approve_percent': 43.0, 'disapprove_percent': 50.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb57'), 'survey_organization': 'YouGov', 'survey_sample': 749.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 27, 0, 0), 'end_date': datetime.datetime(2020, 2, 29, 0, 0), 'approve_percent': 46.0, 'disapprove_percent': 53.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb58'), 'survey_organization': 'IBD/TIPP', 'survey_sample': 901.0, 'survey_population': 'Adults', 'survey_method': 'Live Phone', 'start_date': datetime.datetime(2020, 2, 20, 0, 0), 'end_date': datetime.datetime(2020, 2, 29, 0, 0), 'approve_percent': 41.0, 'disapprove_percent': 54.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb59'), 'survey_organization': 'YouGov', 'survey_sample': 1000.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 26, 0, 0), 'end_date': datetime.datetime(2020, 2, 28, 0, 0), 'approve_percent': 41.0, 'disapprove_percent': 50.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb5a'), 'survey_organization': 'YouGov', 'survey_sample': 760.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 26, 0, 0), 'end_date': datetime.datetime(2020, 2, 28, 0, 0), 'approve_percent': 45.0, 'disapprove_percent': 53.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb5b'), 'survey_organization': 'Gallup', 'survey_sample': 1020.0, 'survey_population': 'Adults', 'survey_method': 'Live Phone', 'start_date': datetime.datetime(2020, 2, 17, 0, 0), 'end_date': datetime.datetime(2020, 2, 28, 0, 0), 'approve_percent': 47.0, 'disapprove_percent': 51.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb5c'), 'survey_organization': 'YouGov', 'survey_sample': 1662.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 26, 0, 0), 'end_date': datetime.datetime(2020, 2, 27, 0, 0), 'approve_percent': 44.0, 'disapprove_percent': 55.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb5d'), 'survey_organization': 'Rasmussen Reports/Pulse Opinion Research', 'survey_sample': 1500.0, 'survey_population': 'Likely Voters', 'survey_method': 'IVR/Online', 'start_date': datetime.datetime(2020, 2, 25, 0, 0), 'end_date': datetime.datetime(2020, 2, 27, 0, 0), 'approve_percent': 47.0, 'disapprove_percent': 52.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb5e'), 'survey_organization': 'YouGov', 'survey_sample': 1000.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 25, 0, 0), 'end_date': datetime.datetime(2020, 2, 27, 0, 0), 'approve_percent': 41.0, 'disapprove_percent': 53.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb5f'), 'survey_organization': 'YouGov', 'survey_sample': 840.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 25, 0, 0), 'end_date': datetime.datetime(2020, 2, 27, 0, 0), 'approve_percent': 42.0, 'disapprove_percent': 55.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb60'), 'survey_organization': 'Morning Consult', 'survey_sample': 2200.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 24, 0, 0), 'end_date': datetime.datetime(2020, 2, 26, 0, 0), 'approve_percent': 42.0, 'disapprove_percent': 53.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb61'), 'survey_organization': 'Morning Consult', 'survey_sample': 1994.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 24, 0, 0), 'end_date': datetime.datetime(2020, 2, 26, 0, 0), 'approve_percent': 43.0, 'disapprove_percent': 55.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb62'), 'survey_organization': 'Rasmussen Reports/Pulse Opinion Research', 'survey_sample': 1500.0, 'survey_population': 'Likely Voters', 'survey_method': 'IVR/Online', 'start_date': datetime.datetime(2020, 2, 24, 0, 0), 'end_date': datetime.datetime(2020, 2, 26, 0, 0), 'approve_percent': 52.0, 'disapprove_percent': 47.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb63'), 'survey_organization': 'Fox News/Beacon Research/Shaw & Co. Research', 'survey_sample': 1000.0, 'survey_population': 'Registered Voters', 'survey_method': 'Live Phone', 'start_date': datetime.datetime(2020, 2, 23, 0, 0), 'end_date': datetime.datetime(2020, 2, 26, 0, 0), 'approve_percent': 47.0, 'disapprove_percent': 52.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb64'), 'survey_organization': 'YouGov', 'survey_sample': 1000.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 24, 0, 0), 'end_date': datetime.datetime(2020, 2, 25, 0, 0), 'approve_percent': 41.0, 'disapprove_percent': 51.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb65'), 'survey_organization': 'YouGov', 'survey_sample': 748.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 24, 0, 0), 'end_date': datetime.datetime(2020, 2, 25, 0, 0), 'approve_percent': 43.0, 'disapprove_percent': 56.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb66'), 'survey_organization': 'YouGov', 'survey_sample': 1500.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 23, 0, 0), 'end_date': datetime.datetime(2020, 2, 25, 0, 0), 'approve_percent': 42.0, 'disapprove_percent': 50.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb67'), 'survey_organization': 'YouGov', 'survey_sample': 1184.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 23, 0, 0), 'end_date': datetime.datetime(2020, 2, 25, 0, 0), 'approve_percent': 44.0, 'disapprove_percent': 53.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb68'), 'survey_organization': 'Rasmussen Reports/Pulse Opinion Research', 'survey_sample': 1500.0, 'survey_population': 'Likely Voters', 'survey_method': 'IVR/Online', 'start_date': datetime.datetime(2020, 2, 23, 0, 0), 'end_date': datetime.datetime(2020, 2, 25, 0, 0), 'approve_percent': 51.0, 'disapprove_percent': 48.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb69'), 'survey_organization': 'YouGov', 'survey_sample': 1000.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 23, 0, 0), 'end_date': datetime.datetime(2020, 2, 25, 0, 0), 'approve_percent': 42.0, 'disapprove_percent': 51.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb6a'), 'survey_organization': 'YouGov', 'survey_sample': 807.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 23, 0, 0), 'end_date': datetime.datetime(2020, 2, 25, 0, 0), 'approve_percent': 47.0, 'disapprove_percent': 51.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb6b'), 'survey_organization': 'Ipsos', 'survey_sample': 4439.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 19, 0, 0), 'end_date': datetime.datetime(2020, 2, 25, 0, 0), 'approve_percent': 42.0, 'disapprove_percent': 54.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb6c'), 'survey_organization': 'Ipsos', 'survey_sample': 3809.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 19, 0, 0), 'end_date': datetime.datetime(2020, 2, 25, 0, 0), 'approve_percent': 43.0, 'disapprove_percent': 55.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb6d'), 'survey_organization': 'YouGov', 'survey_sample': 1000.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 22, 0, 0), 'end_date': datetime.datetime(2020, 2, 24, 0, 0), 'approve_percent': 40.0, 'disapprove_percent': 52.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb6e'), 'survey_organization': 'YouGov', 'survey_sample': 719.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 22, 0, 0), 'end_date': datetime.datetime(2020, 2, 24, 0, 0), 'approve_percent': 42.0, 'disapprove_percent': 56.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb6f'), 'survey_organization': 'Rasmussen Reports/Pulse Opinion Research', 'survey_sample': 1500.0, 'survey_population': 'Likely Voters', 'survey_method': 'IVR/Online', 'start_date': datetime.datetime(2020, 2, 20, 0, 0), 'end_date': datetime.datetime(2020, 2, 24, 0, 0), 'approve_percent': 52.0, 'disapprove_percent': 47.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb70'), 'survey_organization': 'Morning Consult', 'survey_sample': 1989.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 23, 0, 0), 'end_date': datetime.datetime(2020, 2, 23, 0, 0), 'approve_percent': 42.0, 'disapprove_percent': 55.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb71'), 'survey_organization': 'Morning Consult', 'survey_sample': 1992.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 21, 0, 0), 'end_date': datetime.datetime(2020, 2, 23, 0, 0), 'approve_percent': 45.0, 'disapprove_percent': 52.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb72'), 'survey_organization': 'Morning Consult', 'survey_sample': 2200.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 21, 0, 0), 'end_date': datetime.datetime(2020, 2, 23, 0, 0), 'approve_percent': 41.0, 'disapprove_percent': 55.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb73'), 'survey_organization': 'YouGov', 'survey_sample': 1000.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 21, 0, 0), 'end_date': datetime.datetime(2020, 2, 23, 0, 0), 'approve_percent': 40.0, 'disapprove_percent': 50.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb74'), 'survey_organization': 'YouGov', 'survey_sample': 740.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 21, 0, 0), 'end_date': datetime.datetime(2020, 2, 23, 0, 0), 'approve_percent': 44.0, 'disapprove_percent': 53.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb75'), 'survey_organization': 'Morning Consult', 'survey_sample': 6600.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 20, 0, 0), 'end_date': datetime.datetime(2020, 2, 23, 0, 0), 'approve_percent': 41.0, 'disapprove_percent': 55.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb76'), 'survey_organization': 'Morning Consult', 'survey_sample': 5969.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 20, 0, 0), 'end_date': datetime.datetime(2020, 2, 23, 0, 0), 'approve_percent': 42.0, 'disapprove_percent': 55.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb77'), 'survey_organization': 'Rasmussen Reports/Pulse Opinion Research', 'survey_sample': 1500.0, 'survey_population': 'Likely Voters', 'survey_method': 'IVR/Online', 'start_date': datetime.datetime(2020, 2, 19, 0, 0), 'end_date': datetime.datetime(2020, 2, 23, 0, 0), 'approve_percent': 49.0, 'disapprove_percent': 50.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb78'), 'survey_organization': 'YouGov', 'survey_sample': 1000.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 20, 0, 0), 'end_date': datetime.datetime(2020, 2, 22, 0, 0), 'approve_percent': 41.0, 'disapprove_percent': 50.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb79'), 'survey_organization': 'YouGov', 'survey_sample': 681.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 20, 0, 0), 'end_date': datetime.datetime(2020, 2, 22, 0, 0), 'approve_percent': 43.0, 'disapprove_percent': 54.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb7a'), 'survey_organization': 'Saint Leo University', 'survey_sample': 1000.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 17, 0, 0), 'end_date': datetime.datetime(2020, 2, 22, 0, 0), 'approve_percent': 44.3, 'disapprove_percent': 53.7, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb7b'), 'survey_organization': 'YouGov', 'survey_sample': 1000.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 19, 0, 0), 'end_date': datetime.datetime(2020, 2, 21, 0, 0), 'approve_percent': 41.0, 'disapprove_percent': 53.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb7c'), 'survey_organization': 'YouGov', 'survey_sample': 732.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 19, 0, 0), 'end_date': datetime.datetime(2020, 2, 21, 0, 0), 'approve_percent': 42.0, 'disapprove_percent': 56.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb7d'), 'survey_organization': 'YouGov', 'survey_sample': 1000.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 18, 0, 0), 'end_date': datetime.datetime(2020, 2, 20, 0, 0), 'approve_percent': 41.0, 'disapprove_percent': 52.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb7e'), 'survey_organization': 'YouGov', 'survey_sample': 775.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 18, 0, 0), 'end_date': datetime.datetime(2020, 2, 20, 0, 0), 'approve_percent': 43.0, 'disapprove_percent': 54.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb7f'), 'survey_organization': 'Rasmussen Reports/Pulse Opinion Research', 'survey_sample': 1500.0, 'survey_population': 'Likely Voters', 'survey_method': 'IVR/Online', 'start_date': datetime.datetime(2020, 2, 18, 0, 0), 'end_date': datetime.datetime(2020, 2, 20, 0, 0), 'approve_percent': 49.0, 'disapprove_percent': 51.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb80'), 'survey_organization': 'American Research Group', 'survey_sample': 1100.0, 'survey_population': 'Adults', 'survey_method': 'Live Phone', 'start_date': datetime.datetime(2020, 2, 17, 0, 0), 'end_date': datetime.datetime(2020, 2, 20, 0, 0), 'approve_percent': 37.0, 'disapprove_percent': 59.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb81'), 'survey_organization': 'American Research Group', 'survey_sample': 993.0, 'survey_population': 'Registered Voters', 'survey_method': 'Live Phone', 'start_date': datetime.datetime(2020, 2, 17, 0, 0), 'end_date': datetime.datetime(2020, 2, 20, 0, 0), 'approve_percent': 36.0, 'disapprove_percent': 60.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb82'), 'survey_organization': 'Ipsos', 'survey_sample': 1113.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 18, 0, 0), 'end_date': datetime.datetime(2020, 2, 19, 0, 0), 'approve_percent': 41.0, 'disapprove_percent': 56.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb83'), 'survey_organization': 'Ipsos', 'survey_sample': 951.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 18, 0, 0), 'end_date': datetime.datetime(2020, 2, 19, 0, 0), 'approve_percent': 43.0, 'disapprove_percent': 55.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb84'), 'survey_organization': 'YouGov', 'survey_sample': 1000.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 17, 0, 0), 'end_date': datetime.datetime(2020, 2, 19, 0, 0), 'approve_percent': 44.0, 'disapprove_percent': 49.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb85'), 'survey_organization': 'YouGov', 'survey_sample': 732.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 17, 0, 0), 'end_date': datetime.datetime(2020, 2, 19, 0, 0), 'approve_percent': 46.0, 'disapprove_percent': 52.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb86'), 'survey_organization': 'Rasmussen Reports/Pulse Opinion Research', 'survey_sample': 1500.0, 'survey_population': 'Likely Voters', 'survey_method': 'IVR/Online', 'start_date': datetime.datetime(2020, 2, 17, 0, 0), 'end_date': datetime.datetime(2020, 2, 19, 0, 0), 'approve_percent': 49.0, 'disapprove_percent': 50.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb87'), 'survey_organization': 'Emerson College', 'survey_sample': 1250.0, 'survey_population': 'Registered Voters', 'survey_method': 'IVR/Online', 'start_date': datetime.datetime(2020, 2, 16, 0, 0), 'end_date': datetime.datetime(2020, 2, 18, 0, 0), 'approve_percent': 48.0, 'disapprove_percent': 44.3, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb88'), 'survey_organization': 'Rasmussen Reports/Pulse Opinion Research', 'survey_sample': 1500.0, 'survey_population': 'Likely Voters', 'survey_method': 'IVR/Online', 'start_date': datetime.datetime(2020, 2, 16, 0, 0), 'end_date': datetime.datetime(2020, 2, 18, 0, 0), 'approve_percent': 50.0, 'disapprove_percent': 49.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb89'), 'survey_organization': 'YouGov', 'survey_sample': 1500.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 16, 0, 0), 'end_date': datetime.datetime(2020, 2, 18, 0, 0), 'approve_percent': 40.0, 'disapprove_percent': 52.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb8a'), 'survey_organization': 'YouGov', 'survey_sample': 1150.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 16, 0, 0), 'end_date': datetime.datetime(2020, 2, 18, 0, 0), 'approve_percent': 43.0, 'disapprove_percent': 54.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb8b'), 'survey_organization': 'YouGov', 'survey_sample': 1000.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 16, 0, 0), 'end_date': datetime.datetime(2020, 2, 18, 0, 0), 'approve_percent': 42.0, 'disapprove_percent': 48.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb8c'), 'survey_organization': 'YouGov', 'survey_sample': 785.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 16, 0, 0), 'end_date': datetime.datetime(2020, 2, 18, 0, 0), 'approve_percent': 45.0, 'disapprove_percent': 52.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb8d'), 'survey_organization': 'Kaiser Family Foundation', 'survey_sample': 1207.0, 'survey_population': 'Adults', 'survey_method': 'Live Phone', 'start_date': datetime.datetime(2020, 2, 13, 0, 0), 'end_date': datetime.datetime(2020, 2, 18, 0, 0), 'approve_percent': 42.0, 'disapprove_percent': 54.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb8e'), 'survey_organization': 'YouGov', 'survey_sample': 1000.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 15, 0, 0), 'end_date': datetime.datetime(2020, 2, 17, 0, 0), 'approve_percent': 42.0, 'disapprove_percent': 52.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb8f'), 'survey_organization': 'YouGov', 'survey_sample': 753.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 15, 0, 0), 'end_date': datetime.datetime(2020, 2, 17, 0, 0), 'approve_percent': 44.0, 'disapprove_percent': 54.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb90'), 'survey_organization': 'Morning Consult', 'survey_sample': 1990.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 15, 0, 0), 'end_date': datetime.datetime(2020, 2, 17, 0, 0), 'approve_percent': 42.0, 'disapprove_percent': 54.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb91'), 'survey_organization': 'NBC News/Wall Street Journal', 'survey_sample': 900.0, 'survey_population': 'Registered Voters', 'survey_method': 'Live Phone', 'start_date': datetime.datetime(2020, 2, 14, 0, 0), 'end_date': datetime.datetime(2020, 2, 17, 0, 0), 'approve_percent': 47.0, 'disapprove_percent': 50.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb92'), 'survey_organization': 'ABC News/Washington Post', 'survey_sample': 1066.0, 'survey_population': 'Adults', 'survey_method': 'Live Phone', 'start_date': datetime.datetime(2020, 2, 14, 0, 0), 'end_date': datetime.datetime(2020, 2, 17, 0, 0), 'approve_percent': 43.0, 'disapprove_percent': 53.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb93'), 'survey_organization': 'ABC News/Washington Post', 'survey_sample': 913.0, 'survey_population': 'Registered Voters', 'survey_method': 'Live Phone', 'start_date': datetime.datetime(2020, 2, 14, 0, 0), 'end_date': datetime.datetime(2020, 2, 17, 0, 0), 'approve_percent': 46.0, 'disapprove_percent': 52.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb94'), 'survey_organization': 'Global Strategy Group/GBA Strategies', 'survey_sample': 1200.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 14, 0, 0), 'end_date': datetime.datetime(2020, 2, 17, 0, 0), 'approve_percent': 45.0, 'disapprove_percent': 53.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb95'), 'survey_organization': 'Rasmussen Reports/Pulse Opinion Research', 'survey_sample': 1500.0, 'survey_population': 'Likely Voters', 'survey_method': 'IVR/Online', 'start_date': datetime.datetime(2020, 2, 13, 0, 0), 'end_date': datetime.datetime(2020, 2, 17, 0, 0), 'approve_percent': 50.0, 'disapprove_percent': 49.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb96'), 'survey_organization': 'SurveyUSA', 'survey_sample': 2768.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 13, 0, 0), 'end_date': datetime.datetime(2020, 2, 17, 0, 0), 'approve_percent': 44.0, 'disapprove_percent': 52.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb97'), 'survey_organization': 'YouGov', 'survey_sample': 1000.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 14, 0, 0), 'end_date': datetime.datetime(2020, 2, 16, 0, 0), 'approve_percent': 42.0, 'disapprove_percent': 51.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb98'), 'survey_organization': 'YouGov', 'survey_sample': 715.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 14, 0, 0), 'end_date': datetime.datetime(2020, 2, 16, 0, 0), 'approve_percent': 44.0, 'disapprove_percent': 54.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb99'), 'survey_organization': 'Marist College', 'survey_sample': 1416.0, 'survey_population': 'Adults', 'survey_method': 'Live Phone', 'start_date': datetime.datetime(2020, 2, 13, 0, 0), 'end_date': datetime.datetime(2020, 2, 16, 0, 0), 'approve_percent': 42.0, 'disapprove_percent': 51.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb9a'), 'survey_organization': 'Marist College', 'survey_sample': 1164.0, 'survey_population': 'Registered Voters', 'survey_method': 'Live Phone', 'start_date': datetime.datetime(2020, 2, 13, 0, 0), 'end_date': datetime.datetime(2020, 2, 16, 0, 0), 'approve_percent': 44.0, 'disapprove_percent': 51.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb9b'), 'survey_organization': 'AP-NORC', 'survey_sample': 1074.0, 'survey_population': 'Adults', 'survey_method': 'Live Phone/Online', 'start_date': datetime.datetime(2020, 2, 13, 0, 0), 'end_date': datetime.datetime(2020, 2, 16, 0, 0), 'approve_percent': 43.0, 'disapprove_percent': 56.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb9c'), 'survey_organization': 'AP-NORC', 'survey_sample': 922.0, 'survey_population': 'Registered Voters', 'survey_method': 'Live Phone/Online', 'start_date': datetime.datetime(2020, 2, 13, 0, 0), 'end_date': datetime.datetime(2020, 2, 16, 0, 0), 'approve_percent': 43.0, 'disapprove_percent': 56.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb9d'), 'survey_organization': 'Rasmussen Reports/Pulse Opinion Research', 'survey_sample': 1500.0, 'survey_population': 'Likely Voters', 'survey_method': 'IVR/Online', 'start_date': datetime.datetime(2020, 2, 12, 0, 0), 'end_date': datetime.datetime(2020, 2, 16, 0, 0), 'approve_percent': 49.0, 'disapprove_percent': 50.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb9e'), 'survey_organization': 'Gallup', 'survey_sample': 1028.0, 'survey_population': 'Adults', 'survey_method': 'Live Phone', 'start_date': datetime.datetime(2020, 2, 3, 0, 0), 'end_date': datetime.datetime(2020, 2, 16, 0, 0), 'approve_percent': 49.0, 'disapprove_percent': 48.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fb9f'), 'survey_organization': 'Harris Insights & Analytics', 'survey_sample': 1001.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 14, 0, 0), 'end_date': datetime.datetime(2020, 2, 15, 0, 0), 'approve_percent': 49.0, 'disapprove_percent': 51.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fba0'), 'survey_organization': 'YouGov', 'survey_sample': 1000.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 13, 0, 0), 'end_date': datetime.datetime(2020, 2, 15, 0, 0), 'approve_percent': 42.0, 'disapprove_percent': 51.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fba1'), 'survey_organization': 'YouGov', 'survey_sample': 717.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 13, 0, 0), 'end_date': datetime.datetime(2020, 2, 15, 0, 0), 'approve_percent': 44.0, 'disapprove_percent': 54.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fba2'), 'survey_organization': 'Morning Consult', 'survey_sample': 2200.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 13, 0, 0), 'end_date': datetime.datetime(2020, 2, 15, 0, 0), 'approve_percent': 43.0, 'disapprove_percent': 52.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fba3'), 'survey_organization': 'Morning Consult', 'survey_sample': 6600.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 13, 0, 0), 'end_date': datetime.datetime(2020, 2, 15, 0, 0), 'approve_percent': 42.0, 'disapprove_percent': 53.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fba4'), 'survey_organization': 'YouGov', 'survey_sample': 1000.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 12, 0, 0), 'end_date': datetime.datetime(2020, 2, 15, 0, 0), 'approve_percent': 42.0, 'disapprove_percent': 48.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fba5'), 'survey_organization': 'YouGov', 'survey_sample': 707.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 12, 0, 0), 'end_date': datetime.datetime(2020, 2, 15, 0, 0), 'approve_percent': 46.0, 'disapprove_percent': 50.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fba6'), 'survey_organization': 'Zogby Interactive/JZ Analytics', 'survey_sample': 1340.0, 'survey_population': 'Likely Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 13, 0, 0), 'end_date': datetime.datetime(2020, 2, 14, 0, 0), 'approve_percent': 51.0, 'disapprove_percent': 47.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fba7'), 'survey_organization': 'Civiqs', 'survey_sample': 1543.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 11, 0, 0), 'end_date': datetime.datetime(2020, 2, 14, 0, 0), 'approve_percent': 45.0, 'disapprove_percent': 52.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fba8'), 'survey_organization': 'YouGov', 'survey_sample': 1200.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 3, 0, 0), 'end_date': datetime.datetime(2020, 2, 14, 0, 0), 'approve_percent': 43.1, 'disapprove_percent': 51.9, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fba9'), 'survey_organization': 'YouGov', 'survey_sample': 1530.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 12, 0, 0), 'end_date': datetime.datetime(2020, 2, 13, 0, 0), 'approve_percent': 46.0, 'disapprove_percent': 52.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fbaa'), 'survey_organization': 'Rasmussen Reports/Pulse Opinion Research', 'survey_sample': 1500.0, 'survey_population': 'Likely Voters', 'survey_method': 'IVR/Online', 'start_date': datetime.datetime(2020, 2, 11, 0, 0), 'end_date': datetime.datetime(2020, 2, 13, 0, 0), 'approve_percent': 49.0, 'disapprove_percent': 49.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fbab'), 'survey_organization': 'YouGov', 'survey_sample': 1000.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 11, 0, 0), 'end_date': datetime.datetime(2020, 2, 13, 0, 0), 'approve_percent': 42.0, 'disapprove_percent': 49.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fbac'), 'survey_organization': 'YouGov', 'survey_sample': 819.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 11, 0, 0), 'end_date': datetime.datetime(2020, 2, 13, 0, 0), 'approve_percent': 44.0, 'disapprove_percent': 54.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fbad'), 'survey_organization': 'Morning Consult', 'survey_sample': 1993.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 12, 0, 0), 'end_date': datetime.datetime(2020, 2, 12, 0, 0), 'approve_percent': 41.0, 'disapprove_percent': 56.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fbae'), 'survey_organization': 'YouGov', 'survey_sample': 1000.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 10, 0, 0), 'end_date': datetime.datetime(2020, 2, 12, 0, 0), 'approve_percent': 40.0, 'disapprove_percent': 51.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fbaf'), 'survey_organization': 'YouGov', 'survey_sample': 750.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 10, 0, 0), 'end_date': datetime.datetime(2020, 2, 12, 0, 0), 'approve_percent': 44.0, 'disapprove_percent': 54.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fbb0'), 'survey_organization': 'Rasmussen Reports/Pulse Opinion Research', 'survey_sample': 1500.0, 'survey_population': 'Likely Voters', 'survey_method': 'IVR/Online', 'start_date': datetime.datetime(2020, 2, 10, 0, 0), 'end_date': datetime.datetime(2020, 2, 12, 0, 0), 'approve_percent': 50.0, 'disapprove_percent': 49.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fbb1'), 'survey_organization': 'Ipsos', 'survey_sample': 1114.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 10, 0, 0), 'end_date': datetime.datetime(2020, 2, 11, 0, 0), 'approve_percent': 41.0, 'disapprove_percent': 54.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fbb2'), 'survey_organization': 'Ipsos', 'survey_sample': 959.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 10, 0, 0), 'end_date': datetime.datetime(2020, 2, 11, 0, 0), 'approve_percent': 44.0, 'disapprove_percent': 54.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fbb3'), 'survey_organization': 'YouGov', 'survey_sample': 1000.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 9, 0, 0), 'end_date': datetime.datetime(2020, 2, 11, 0, 0), 'approve_percent': 40.0, 'disapprove_percent': 51.0, 'undecided_percent': nan, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1464fbb4'), 'survey_organization': 'YouGov', 'survey_sample': 737.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2020, 2, 9, 0, 0), 'end_date': datetime.datetime(2020, 2, 11, 0, 0), 'approve_percent': 42.0, 'disapprove_percent': 55.0, 'undecided_percent': nan, 'margin_of_error': nan}
# ...
# {'_id': ObjectId('5e67092800adebab14651696'), 'survey_organization': 'SurveyMonkey', 'survey_sample': 3457.0, 'survey_population': 'Adults (Independents)', 'survey_method': 'Online', 'start_date': datetime.datetime(2017, 2, 13, 0, 0), 'end_date': datetime.datetime(2017, 2, 17, 0, 0), 'approve_percent': 43.0, 'disapprove_percent': 56.0, 'undecided_percent': 0.0, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab14651697'), 'survey_organization': 'Rasmussen Reports/Pulse Opinion Research', 'survey_sample': 1500.0, 'survey_population': 'Likely Voters', 'survey_method': 'Automated Phone/Online', 'start_date': datetime.datetime(2017, 2, 14, 0, 0), 'end_date': datetime.datetime(2017, 2, 16, 0, 0), 'approve_percent': 55.0, 'disapprove_percent': 45.0, 'undecided_percent': nan, 'margin_of_error': 2.5}
# {'_id': ObjectId('5e67092800adebab14651698'), 'survey_organization': 'McClatchy/Marist', 'survey_sample': 864.0, 'survey_population': 'Registered Voters', 'survey_method': 'Live Phone', 'start_date': datetime.datetime(2017, 2, 15, 0, 0), 'end_date': datetime.datetime(2017, 2, 19, 0, 0), 'approve_percent': 41.0, 'disapprove_percent': 49.0, 'undecided_percent': 9.0, 'margin_of_error': 3.3}
# {'_id': ObjectId('5e67092800adebab14651699'), 'survey_organization': 'McClatchy/Marist', 'survey_sample': nan, 'survey_population': 'Registered Voters (Democrats)', 'survey_method': 'Live Phone', 'start_date': datetime.datetime(2017, 2, 15, 0, 0), 'end_date': datetime.datetime(2017, 2, 19, 0, 0), 'approve_percent': 11.0, 'disapprove_percent': 81.0, 'undecided_percent': 8.0, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1465169a'), 'survey_organization': 'McClatchy/Marist', 'survey_sample': nan, 'survey_population': 'Registered Voters (Republicans)', 'survey_method': 'Live Phone', 'start_date': datetime.datetime(2017, 2, 15, 0, 0), 'end_date': datetime.datetime(2017, 2, 19, 0, 0), 'approve_percent': 85.0, 'disapprove_percent': 7.0, 'undecided_percent': 8.0, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1465169b'), 'survey_organization': 'McClatchy/Marist', 'survey_sample': nan, 'survey_population': 'Registered Voters (Independents)', 'survey_method': 'Live Phone', 'start_date': datetime.datetime(2017, 2, 15, 0, 0), 'end_date': datetime.datetime(2017, 2, 19, 0, 0), 'approve_percent': 40.0, 'disapprove_percent': 51.0, 'undecided_percent': 9.0, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1465169c'), 'survey_organization': 'Rasmussen Reports/Pulse Opinion Research', 'survey_sample': 1500.0, 'survey_population': 'Likely Voters', 'survey_method': 'Automated Phone/Online', 'start_date': datetime.datetime(2017, 2, 15, 0, 0), 'end_date': datetime.datetime(2017, 2, 19, 0, 0), 'approve_percent': 51.0, 'disapprove_percent': 49.0, 'undecided_percent': nan, 'margin_of_error': 2.5}
# {'_id': ObjectId('5e67092800adebab1465169d'), 'survey_organization': 'Politico/Morning Consult', 'survey_sample': 2013.0, 'survey_population': 'Registered Voters', 'survey_method': 'Online', 'start_date': datetime.datetime(2017, 2, 16, 0, 0), 'end_date': datetime.datetime(2017, 2, 19, 0, 0), 'approve_percent': 49.0, 'disapprove_percent': 44.0, 'undecided_percent': 7.0, 'margin_of_error': 2.0}
# {'_id': ObjectId('5e67092800adebab1465169e'), 'survey_organization': 'Politico/Morning Consult', 'survey_sample': 691.0, 'survey_population': 'Registered Voters (Democrats)', 'survey_method': 'Online', 'start_date': datetime.datetime(2017, 2, 16, 0, 0), 'end_date': datetime.datetime(2017, 2, 19, 0, 0), 'approve_percent': 21.0, 'disapprove_percent': 74.0, 'undecided_percent': 5.0, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab1465169f'), 'survey_organization': 'Politico/Morning Consult', 'survey_sample': 648.0, 'survey_population': 'Registered Voters (Republicans)', 'survey_method': 'Online', 'start_date': datetime.datetime(2017, 2, 16, 0, 0), 'end_date': datetime.datetime(2017, 2, 19, 0, 0), 'approve_percent': 85.0, 'disapprove_percent': 11.0, 'undecided_percent': 4.0, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab146516a0'), 'survey_organization': 'Politico/Morning Consult', 'survey_sample': 675.0, 'survey_population': 'Registered Voters (Independents)', 'survey_method': 'Online', 'start_date': datetime.datetime(2017, 2, 16, 0, 0), 'end_date': datetime.datetime(2017, 2, 19, 0, 0), 'approve_percent': 41.0, 'disapprove_percent': 47.0, 'undecided_percent': 13.0, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab146516a1'), 'survey_organization': 'Rasmussen Reports/Pulse Opinion Research', 'survey_sample': 1500.0, 'survey_population': 'Likely Voters', 'survey_method': 'Automated Phone/Online', 'start_date': datetime.datetime(2017, 2, 16, 0, 0), 'end_date': datetime.datetime(2017, 2, 20, 0, 0), 'approve_percent': 50.0, 'disapprove_percent': 50.0, 'undecided_percent': nan, 'margin_of_error': 2.5}
# {'_id': ObjectId('5e67092800adebab146516a2'), 'survey_organization': 'CBS', 'survey_sample': 1280.0, 'survey_population': 'Adults', 'survey_method': 'Live Phone', 'start_date': datetime.datetime(2017, 2, 17, 0, 0), 'end_date': datetime.datetime(2017, 2, 21, 0, 0), 'approve_percent': 39.0, 'disapprove_percent': 51.0, 'undecided_percent': 10.0, 'margin_of_error': 3.0}
# {'_id': ObjectId('5e67092800adebab146516a3'), 'survey_organization': 'CBS', 'survey_sample': 386.0, 'survey_population': 'Adults (Democrats)', 'survey_method': 'Live Phone', 'start_date': datetime.datetime(2017, 2, 17, 0, 0), 'end_date': datetime.datetime(2017, 2, 21, 0, 0), 'approve_percent': 6.0, 'disapprove_percent': 85.0, 'undecided_percent': 9.0, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab146516a4'), 'survey_organization': 'CBS', 'survey_sample': 355.0, 'survey_population': 'Adults (Republicans)', 'survey_method': 'Live Phone', 'start_date': datetime.datetime(2017, 2, 17, 0, 0), 'end_date': datetime.datetime(2017, 2, 21, 0, 0), 'approve_percent': 82.0, 'disapprove_percent': 11.0, 'undecided_percent': 6.0, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab146516a5'), 'survey_organization': 'CBS', 'survey_sample': 549.0, 'survey_population': 'Adults (Independents)', 'survey_method': 'Live Phone', 'start_date': datetime.datetime(2017, 2, 17, 0, 0), 'end_date': datetime.datetime(2017, 2, 21, 0, 0), 'approve_percent': 37.0, 'disapprove_percent': 50.0, 'undecided_percent': 12.0, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab146516a6'), 'survey_organization': 'HuffPost/YouGov', 'survey_sample': 1000.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2017, 2, 17, 0, 0), 'end_date': datetime.datetime(2017, 2, 18, 0, 0), 'approve_percent': 41.0, 'disapprove_percent': 47.0, 'undecided_percent': 12.0, 'margin_of_error': 4.0}
# {'_id': ObjectId('5e67092800adebab146516a7'), 'survey_organization': 'HuffPost/YouGov', 'survey_sample': 363.0, 'survey_population': 'Adults (Democrats)', 'survey_method': 'Online', 'start_date': datetime.datetime(2017, 2, 17, 0, 0), 'end_date': datetime.datetime(2017, 2, 18, 0, 0), 'approve_percent': 17.0, 'disapprove_percent': 75.0, 'undecided_percent': 8.0, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab146516a8'), 'survey_organization': 'HuffPost/YouGov', 'survey_sample': 264.0, 'survey_population': 'Adults (Republicans)', 'survey_method': 'Online', 'start_date': datetime.datetime(2017, 2, 17, 0, 0), 'end_date': datetime.datetime(2017, 2, 18, 0, 0), 'approve_percent': 84.0, 'disapprove_percent': 11.0, 'undecided_percent': 5.0, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab146516a9'), 'survey_organization': 'HuffPost/YouGov', 'survey_sample': 373.0, 'survey_population': 'Adults (Independents)', 'survey_method': 'Online', 'start_date': datetime.datetime(2017, 2, 17, 0, 0), 'end_date': datetime.datetime(2017, 2, 18, 0, 0), 'approve_percent': 37.0, 'disapprove_percent': 44.0, 'undecided_percent': 19.0, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab146516aa'), 'survey_organization': 'Ipsos', 'survey_sample': 2338.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2017, 2, 17, 0, 0), 'end_date': datetime.datetime(2017, 2, 21, 0, 0), 'approve_percent': 45.0, 'disapprove_percent': 50.0, 'undecided_percent': 5.0, 'margin_of_error': 2.3}
# {'_id': ObjectId('5e67092800adebab146516ab'), 'survey_organization': 'Ipsos', 'survey_sample': 996.0, 'survey_population': 'Adults (Democrats)', 'survey_method': 'Online', 'start_date': datetime.datetime(2017, 2, 17, 0, 0), 'end_date': datetime.datetime(2017, 2, 21, 0, 0), 'approve_percent': 19.0, 'disapprove_percent': 79.0, 'undecided_percent': 2.0, 'margin_of_error': 3.5}
# {'_id': ObjectId('5e67092800adebab146516ac'), 'survey_organization': 'Ipsos', 'survey_sample': 867.0, 'survey_population': 'Adults (Republicans)', 'survey_method': 'Online', 'start_date': datetime.datetime(2017, 2, 17, 0, 0), 'end_date': datetime.datetime(2017, 2, 21, 0, 0), 'approve_percent': 82.0, 'disapprove_percent': 16.0, 'undecided_percent': 2.0, 'margin_of_error': 3.8}
# {'_id': ObjectId('5e67092800adebab146516ad'), 'survey_organization': 'Ipsos', 'survey_sample': 290.0, 'survey_population': 'Adults (Independents)', 'survey_method': 'Online', 'start_date': datetime.datetime(2017, 2, 17, 0, 0), 'end_date': datetime.datetime(2017, 2, 21, 0, 0), 'approve_percent': 39.0, 'disapprove_percent': 53.0, 'undecided_percent': 8.0, 'margin_of_error': 6.6}
# {'_id': ObjectId('5e67092800adebab146516ae'), 'survey_organization': 'SurveyMonkey', 'survey_sample': 10639.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2017, 2, 17, 0, 0), 'end_date': datetime.datetime(2017, 2, 23, 0, 0), 'approve_percent': 44.0, 'disapprove_percent': 54.0, 'undecided_percent': 2.0, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab146516af'), 'survey_organization': 'SurveyMonkey', 'survey_sample': 3460.0, 'survey_population': 'Adults (Democrats)', 'survey_method': 'Online', 'start_date': datetime.datetime(2017, 2, 17, 0, 0), 'end_date': datetime.datetime(2017, 2, 23, 0, 0), 'approve_percent': 10.0, 'disapprove_percent': 88.0, 'undecided_percent': 1.0, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab146516b0'), 'survey_organization': 'SurveyMonkey', 'survey_sample': 2813.0, 'survey_population': 'Adults (Republicans)', 'survey_method': 'Online', 'start_date': datetime.datetime(2017, 2, 17, 0, 0), 'end_date': datetime.datetime(2017, 2, 23, 0, 0), 'approve_percent': 88.0, 'disapprove_percent': 12.0, 'undecided_percent': 1.0, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab146516b1'), 'survey_organization': 'SurveyMonkey', 'survey_sample': 4087.0, 'survey_population': 'Adults (Independents)', 'survey_method': 'Online', 'start_date': datetime.datetime(2017, 2, 17, 0, 0), 'end_date': datetime.datetime(2017, 2, 23, 0, 0), 'approve_percent': 41.0, 'disapprove_percent': 58.0, 'undecided_percent': 1.0, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab146516b2'), 'survey_organization': 'YouGov', 'survey_sample': 1500.0, 'survey_population': 'Adults', 'survey_method': 'Online', 'start_date': datetime.datetime(2017, 2, 18, 0, 0), 'end_date': datetime.datetime(2017, 2, 22, 0, 0), 'approve_percent': 43.0, 'disapprove_percent': 46.0, 'undecided_percent': 11.0, 'margin_of_error': 3.0}
# {'_id': ObjectId('5e67092800adebab146516b3'), 'survey_organization': 'YouGov', 'survey_sample': 562.0, 'survey_population': 'Adults (Democrats)', 'survey_method': 'Online', 'start_date': datetime.datetime(2017, 2, 18, 0, 0), 'end_date': datetime.datetime(2017, 2, 22, 0, 0), 'approve_percent': 18.0, 'disapprove_percent': 78.0, 'undecided_percent': 5.0, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab146516b4'), 'survey_organization': 'YouGov', 'survey_sample': 344.0, 'survey_population': 'Adults (Republicans)', 'survey_method': 'Online', 'start_date': datetime.datetime(2017, 2, 18, 0, 0), 'end_date': datetime.datetime(2017, 2, 22, 0, 0), 'approve_percent': 82.0, 'disapprove_percent': 13.0, 'undecided_percent': 4.0, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab146516b5'), 'survey_organization': 'YouGov', 'survey_sample': 594.0, 'survey_population': 'Adults (Independents)', 'survey_method': 'Online', 'start_date': datetime.datetime(2017, 2, 18, 0, 0), 'end_date': datetime.datetime(2017, 2, 22, 0, 0), 'approve_percent': 39.0, 'disapprove_percent': 41.0, 'undecided_percent': 20.0, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab146516b6'), 'survey_organization': 'Rasmussen Reports/Pulse Opinion Research', 'survey_sample': 1500.0, 'survey_population': 'Likely Voters', 'survey_method': 'Automated Phone/Online', 'start_date': datetime.datetime(2017, 2, 19, 0, 0), 'end_date': datetime.datetime(2017, 2, 21, 0, 0), 'approve_percent': 51.0, 'disapprove_percent': 49.0, 'undecided_percent': nan, 'margin_of_error': 2.5}
# {'_id': ObjectId('5e67092800adebab146516b7'), 'survey_organization': 'Rasmussen Reports/Pulse Opinion Research', 'survey_sample': 1500.0, 'survey_population': 'Likely Voters', 'survey_method': 'Automated Phone/Online', 'start_date': datetime.datetime(2017, 2, 20, 0, 0), 'end_date': datetime.datetime(2017, 2, 22, 0, 0), 'approve_percent': 52.0, 'disapprove_percent': 47.0, 'undecided_percent': nan, 'margin_of_error': 2.5}
# {'_id': ObjectId('5e67092800adebab146516b8'), 'survey_organization': 'PPP (D)', 'survey_sample': 941.0, 'survey_population': 'Likely Voters', 'survey_method': 'Automated Phone/Online', 'start_date': datetime.datetime(2017, 2, 21, 0, 0), 'end_date': datetime.datetime(2017, 2, 22, 0, 0), 'approve_percent': 45.0, 'disapprove_percent': 48.0, 'undecided_percent': 7.0, 'margin_of_error': 3.2}
# {'_id': ObjectId('5e67092800adebab146516b9'), 'survey_organization': 'PPP (D)', 'survey_sample': nan, 'survey_population': 'Likely Voters (Democrats)', 'survey_method': 'Automated Phone/Online', 'start_date': datetime.datetime(2017, 2, 21, 0, 0), 'end_date': datetime.datetime(2017, 2, 22, 0, 0), 'approve_percent': 15.0, 'disapprove_percent': 81.0, 'undecided_percent': 4.0, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab146516ba'), 'survey_organization': 'PPP (D)', 'survey_sample': nan, 'survey_population': 'Likely Voters (Republicans)', 'survey_method': 'Automated Phone/Online', 'start_date': datetime.datetime(2017, 2, 21, 0, 0), 'end_date': datetime.datetime(2017, 2, 22, 0, 0), 'approve_percent': 87.0, 'disapprove_percent': 12.0, 'undecided_percent': 1.0, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab146516bb'), 'survey_organization': 'PPP (D)', 'survey_sample': nan, 'survey_population': 'Likely Voters (Independents)', 'survey_method': 'Automated Phone/Online', 'start_date': datetime.datetime(2017, 2, 21, 0, 0), 'end_date': datetime.datetime(2017, 2, 22, 0, 0), 'approve_percent': 37.0, 'disapprove_percent': 54.0, 'undecided_percent': 8.0, 'margin_of_error': nan}
# {'_id': ObjectId('5e67092800adebab146516bc'), 'survey_organization': 'Rasmussen Reports/Pulse Opinion Research', 'survey_sample': 1500.0, 'survey_population': 'Likely Voters', 'survey_method': 'Automated Phone/Online', 'start_date': datetime.datetime(2017, 2, 21, 0, 0), 'end_date': datetime.datetime(2017, 2, 23, 0, 0), 'approve_percent': 53.0, 'disapprove_percent': 47.0, 'undecided_percent': nan, 'margin_of_error': 2.5}
# {'_id': ObjectId('5e67092800adebab146516bd'), 'survey_organization': 'Rasmussen Reports/Pulse Opinion Research', 'survey_sample': 1500.0, 'survey_population': 'Likely Voters', 'survey_method': 'Automated Phone/Online', 'start_date': datetime.datetime(2017, 2, 23, 0, 0), 'end_date': datetime.datetime(2017, 2, 26, 0, 0), 'approve_percent': 51.0, 'disapprove_percent': 49.0, 'undecided_percent': nan, 'margin_of_error': 2.5}

# %%
# try some experimental queries to verify usability
yougov_polls = db.approval_polls.find({"survey_organization": "YouGov"})
for poll in yougov_polls:
    pprint.pprint(poll)
# Out:
# {'_id': ObjectId('5e67092800adebab1464fb38'),
#  'approve_percent': 41.0,
#  'disapprove_percent': 51.0,
#  'end_date': datetime.datetime(2020, 3, 6, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 3, 4, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb39'),
#  'approve_percent': 44.0,
#  'disapprove_percent': 55.0,
#  'end_date': datetime.datetime(2020, 3, 6, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 3, 4, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 755.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb3a'),
#  'approve_percent': 43.0,
#  'disapprove_percent': 50.0,
#  'end_date': datetime.datetime(2020, 3, 5, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 3, 3, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb3b'),
#  'approve_percent': 45.0,
#  'disapprove_percent': 53.0,
#  'end_date': datetime.datetime(2020, 3, 5, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 3, 3, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 763.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb40'),
#  'approve_percent': 43.0,
#  'disapprove_percent': 51.0,
#  'end_date': datetime.datetime(2020, 3, 4, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 3, 2, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb41'),
#  'approve_percent': 45.0,
#  'disapprove_percent': 53.0,
#  'end_date': datetime.datetime(2020, 3, 4, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 3, 2, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 750.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb46'),
#  'approve_percent': 41.0,
#  'disapprove_percent': 48.0,
#  'end_date': datetime.datetime(2020, 3, 3, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 3, 1, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1500.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb47'),
#  'approve_percent': 44.0,
#  'disapprove_percent': 53.0,
#  'end_date': datetime.datetime(2020, 3, 3, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 3, 1, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 1134.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb48'),
#  'approve_percent': 41.0,
#  'disapprove_percent': 51.0,
#  'end_date': datetime.datetime(2020, 3, 3, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 3, 1, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb49'),
#  'approve_percent': 43.0,
#  'disapprove_percent': 54.0,
#  'end_date': datetime.datetime(2020, 3, 3, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 3, 1, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 732.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb4a'),
#  'approve_percent': 43.0,
#  'disapprove_percent': 51.0,
#  'end_date': datetime.datetime(2020, 3, 3, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 29, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb4b'),
#  'approve_percent': 45.0,
#  'disapprove_percent': 53.0,
#  'end_date': datetime.datetime(2020, 3, 3, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 29, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 790.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb52'),
#  'approve_percent': 38.0,
#  'disapprove_percent': 53.0,
#  'end_date': datetime.datetime(2020, 3, 1, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 28, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb53'),
#  'approve_percent': 43.0,
#  'disapprove_percent': 56.0,
#  'end_date': datetime.datetime(2020, 3, 1, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 28, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 769.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb56'),
#  'approve_percent': 43.0,
#  'disapprove_percent': 50.0,
#  'end_date': datetime.datetime(2020, 2, 29, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 27, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb57'),
#  'approve_percent': 46.0,
#  'disapprove_percent': 53.0,
#  'end_date': datetime.datetime(2020, 2, 29, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 27, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 749.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb59'),
#  'approve_percent': 41.0,
#  'disapprove_percent': 50.0,
#  'end_date': datetime.datetime(2020, 2, 28, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 26, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb5a'),
#  'approve_percent': 45.0,
#  'disapprove_percent': 53.0,
#  'end_date': datetime.datetime(2020, 2, 28, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 26, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 760.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb5c'),
#  'approve_percent': 44.0,
#  'disapprove_percent': 55.0,
#  'end_date': datetime.datetime(2020, 2, 27, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 26, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 1662.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb5e'),
#  'approve_percent': 41.0,
#  'disapprove_percent': 53.0,
#  'end_date': datetime.datetime(2020, 2, 27, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 25, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb5f'),
#  'approve_percent': 42.0,
#  'disapprove_percent': 55.0,
#  'end_date': datetime.datetime(2020, 2, 27, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 25, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 840.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb64'),
#  'approve_percent': 41.0,
#  'disapprove_percent': 51.0,
#  'end_date': datetime.datetime(2020, 2, 25, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 24, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb65'),
#  'approve_percent': 43.0,
#  'disapprove_percent': 56.0,
#  'end_date': datetime.datetime(2020, 2, 25, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 24, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 748.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb66'),
#  'approve_percent': 42.0,
#  'disapprove_percent': 50.0,
#  'end_date': datetime.datetime(2020, 2, 25, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 23, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1500.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb67'),
#  'approve_percent': 44.0,
#  'disapprove_percent': 53.0,
#  'end_date': datetime.datetime(2020, 2, 25, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 23, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 1184.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb69'),
#  'approve_percent': 42.0,
#  'disapprove_percent': 51.0,
#  'end_date': datetime.datetime(2020, 2, 25, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 23, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb6a'),
#  'approve_percent': 47.0,
#  'disapprove_percent': 51.0,
#  'end_date': datetime.datetime(2020, 2, 25, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 23, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 807.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb6d'),
#  'approve_percent': 40.0,
#  'disapprove_percent': 52.0,
#  'end_date': datetime.datetime(2020, 2, 24, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 22, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb6e'),
#  'approve_percent': 42.0,
#  'disapprove_percent': 56.0,
#  'end_date': datetime.datetime(2020, 2, 24, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 22, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 719.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb73'),
#  'approve_percent': 40.0,
#  'disapprove_percent': 50.0,
#  'end_date': datetime.datetime(2020, 2, 23, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 21, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb74'),
#  'approve_percent': 44.0,
#  'disapprove_percent': 53.0,
#  'end_date': datetime.datetime(2020, 2, 23, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 21, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 740.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb78'),
#  'approve_percent': 41.0,
#  'disapprove_percent': 50.0,
#  'end_date': datetime.datetime(2020, 2, 22, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 20, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb79'),
#  'approve_percent': 43.0,
#  'disapprove_percent': 54.0,
#  'end_date': datetime.datetime(2020, 2, 22, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 20, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 681.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb7b'),
#  'approve_percent': 41.0,
#  'disapprove_percent': 53.0,
#  'end_date': datetime.datetime(2020, 2, 21, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 19, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb7c'),
#  'approve_percent': 42.0,
#  'disapprove_percent': 56.0,
#  'end_date': datetime.datetime(2020, 2, 21, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 19, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 732.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb7d'),
#  'approve_percent': 41.0,
#  'disapprove_percent': 52.0,
#  'end_date': datetime.datetime(2020, 2, 20, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 18, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb7e'),
#  'approve_percent': 43.0,
#  'disapprove_percent': 54.0,
#  'end_date': datetime.datetime(2020, 2, 20, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 18, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 775.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb84'),
#  'approve_percent': 44.0,
#  'disapprove_percent': 49.0,
#  'end_date': datetime.datetime(2020, 2, 19, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 17, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb85'),
#  'approve_percent': 46.0,
#  'disapprove_percent': 52.0,
#  'end_date': datetime.datetime(2020, 2, 19, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 17, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 732.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb89'),
#  'approve_percent': 40.0,
#  'disapprove_percent': 52.0,
#  'end_date': datetime.datetime(2020, 2, 18, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 16, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1500.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb8a'),
#  'approve_percent': 43.0,
#  'disapprove_percent': 54.0,
#  'end_date': datetime.datetime(2020, 2, 18, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 16, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 1150.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb8b'),
#  'approve_percent': 42.0,
#  'disapprove_percent': 48.0,
#  'end_date': datetime.datetime(2020, 2, 18, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 16, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb8c'),
#  'approve_percent': 45.0,
#  'disapprove_percent': 52.0,
#  'end_date': datetime.datetime(2020, 2, 18, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 16, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 785.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb8e'),
#  'approve_percent': 42.0,
#  'disapprove_percent': 52.0,
#  'end_date': datetime.datetime(2020, 2, 17, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 15, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb8f'),
#  'approve_percent': 44.0,
#  'disapprove_percent': 54.0,
#  'end_date': datetime.datetime(2020, 2, 17, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 15, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 753.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb97'),
#  'approve_percent': 42.0,
#  'disapprove_percent': 51.0,
#  'end_date': datetime.datetime(2020, 2, 16, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 14, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fb98'),
#  'approve_percent': 44.0,
#  'disapprove_percent': 54.0,
#  'end_date': datetime.datetime(2020, 2, 16, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 14, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 715.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fba0'),
#  'approve_percent': 42.0,
#  'disapprove_percent': 51.0,
#  'end_date': datetime.datetime(2020, 2, 15, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 13, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fba1'),
#  'approve_percent': 44.0,
#  'disapprove_percent': 54.0,
#  'end_date': datetime.datetime(2020, 2, 15, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 13, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 717.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fba4'),
#  'approve_percent': 42.0,
#  'disapprove_percent': 48.0,
#  'end_date': datetime.datetime(2020, 2, 15, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 12, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fba5'),
#  'approve_percent': 46.0,
#  'disapprove_percent': 50.0,
#  'end_date': datetime.datetime(2020, 2, 15, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 12, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 707.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fba8'),
#  'approve_percent': 43.1,
#  'disapprove_percent': 51.9,
#  'end_date': datetime.datetime(2020, 2, 14, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 3, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 1200.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fba9'),
#  'approve_percent': 46.0,
#  'disapprove_percent': 52.0,
#  'end_date': datetime.datetime(2020, 2, 13, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 12, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 1530.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fbab'),
#  'approve_percent': 42.0,
#  'disapprove_percent': 49.0,
#  'end_date': datetime.datetime(2020, 2, 13, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 11, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fbac'),
#  'approve_percent': 44.0,
#  'disapprove_percent': 54.0,
#  'end_date': datetime.datetime(2020, 2, 13, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 11, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 819.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fbae'),
#  'approve_percent': 40.0,
#  'disapprove_percent': 51.0,
#  'end_date': datetime.datetime(2020, 2, 12, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 10, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fbaf'),
#  'approve_percent': 44.0,
#  'disapprove_percent': 54.0,
#  'end_date': datetime.datetime(2020, 2, 12, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 10, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 750.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fbb3'),
#  'approve_percent': 40.0,
#  'disapprove_percent': 51.0,
#  'end_date': datetime.datetime(2020, 2, 11, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 9, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fbb4'),
#  'approve_percent': 42.0,
#  'disapprove_percent': 55.0,
#  'end_date': datetime.datetime(2020, 2, 11, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 9, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 737.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fbb5'),
#  'approve_percent': 40.0,
#  'disapprove_percent': 51.0,
#  'end_date': datetime.datetime(2020, 2, 11, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 9, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1500.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fbb6'),
#  'approve_percent': 45.0,
#  'disapprove_percent': 52.0,
#  'end_date': datetime.datetime(2020, 2, 11, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 9, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 1140.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fbb9'),
#  'approve_percent': 41.0,
#  'disapprove_percent': 52.0,
#  'end_date': datetime.datetime(2020, 2, 10, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 8, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fbba'),
#  'approve_percent': 43.0,
#  'disapprove_percent': 55.0,
#  'end_date': datetime.datetime(2020, 2, 10, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 8, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 703.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fbbc'),
#  'approve_percent': 41.0,
#  'disapprove_percent': 50.0,
#  'end_date': datetime.datetime(2020, 2, 9, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 7, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fbbd'),
#  'approve_percent': 45.0,
#  'disapprove_percent': 52.0,
#  'end_date': datetime.datetime(2020, 2, 9, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 7, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 745.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fbc3'),
#  'approve_percent': 40.0,
#  'disapprove_percent': 53.0,
#  'end_date': datetime.datetime(2020, 2, 9, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 6, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fbc4'),
#  'approve_percent': 44.0,
#  'disapprove_percent': 54.0,
#  'end_date': datetime.datetime(2020, 2, 9, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 6, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 736.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fbc8'),
#  'approve_percent': 43.0,
#  'disapprove_percent': 50.0,
#  'end_date': datetime.datetime(2020, 2, 7, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 5, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fbc9'),
#  'approve_percent': 45.0,
#  'disapprove_percent': 52.0,
#  'end_date': datetime.datetime(2020, 2, 7, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 5, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 750.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fbca'),
#  'approve_percent': 43.0,
#  'disapprove_percent': 48.0,
#  'end_date': datetime.datetime(2020, 2, 7, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 4, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fbcb'),
#  'approve_percent': 48.0,
#  'disapprove_percent': 50.0,
#  'end_date': datetime.datetime(2020, 2, 7, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 4, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 701.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fbd1'),
#  'approve_percent': 41.0,
#  'disapprove_percent': 49.0,
#  'end_date': datetime.datetime(2020, 2, 5, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 3, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fbd2'),
#  'approve_percent': 43.0,
#  'disapprove_percent': 55.0,
#  'end_date': datetime.datetime(2020, 2, 5, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 3, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 722.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fbd6'),
#  'approve_percent': 41.0,
#  'disapprove_percent': 50.0,
#  'end_date': datetime.datetime(2020, 2, 4, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 2, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1500.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fbd7'),
#  'approve_percent': 44.0,
#  'disapprove_percent': 54.0,
#  'end_date': datetime.datetime(2020, 2, 4, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 2, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 1277.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fbd8'),
#  'approve_percent': 42.0,
#  'disapprove_percent': 52.0,
#  'end_date': datetime.datetime(2020, 2, 4, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 2, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fbd9'),
#  'approve_percent': 44.0,
#  'disapprove_percent': 55.0,
#  'end_date': datetime.datetime(2020, 2, 4, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 2, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 710.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fbda'),
#  'approve_percent': 40.0,
#  'disapprove_percent': 52.0,
#  'end_date': datetime.datetime(2020, 2, 3, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 1, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fbdb'),
#  'approve_percent': 44.0,
#  'disapprove_percent': 54.0,
#  'end_date': datetime.datetime(2020, 2, 3, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 2, 1, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 788.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fbe0'),
#  'approve_percent': 40.0,
#  'disapprove_percent': 51.0,
#  'end_date': datetime.datetime(2020, 2, 2, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 31, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fbe1'),
#  'approve_percent': 45.0,
#  'disapprove_percent': 52.0,
#  'end_date': datetime.datetime(2020, 2, 2, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 31, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 729.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fbe5'),
#  'approve_percent': 40.0,
#  'disapprove_percent': 53.0,
#  'end_date': datetime.datetime(2020, 2, 1, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 30, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fbe6'),
#  'approve_percent': 45.0,
#  'disapprove_percent': 54.0,
#  'end_date': datetime.datetime(2020, 2, 1, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 30, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 714.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fbe7'),
#  'approve_percent': 41.0,
#  'disapprove_percent': 52.0,
#  'end_date': datetime.datetime(2020, 1, 31, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 29, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fbe8'),
#  'approve_percent': 44.0,
#  'disapprove_percent': 54.0,
#  'end_date': datetime.datetime(2020, 1, 31, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 29, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 750.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fbed'),
#  'approve_percent': 38.0,
#  'disapprove_percent': 52.0,
#  'end_date': datetime.datetime(2020, 1, 29, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 28, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fbee'),
#  'approve_percent': 43.0,
#  'disapprove_percent': 56.0,
#  'end_date': datetime.datetime(2020, 1, 29, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 28, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 772.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fbf8'),
#  'approve_percent': 43.0,
#  'disapprove_percent': 50.0,
#  'end_date': datetime.datetime(2020, 1, 28, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 27, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fbf9'),
#  'approve_percent': 45.0,
#  'disapprove_percent': 53.0,
#  'end_date': datetime.datetime(2020, 1, 28, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 27, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 808.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fbfa'),
#  'approve_percent': 42.0,
#  'disapprove_percent': 50.0,
#  'end_date': datetime.datetime(2020, 1, 28, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 26, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1500.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fbfb'),
#  'approve_percent': 44.0,
#  'disapprove_percent': 53.0,
#  'end_date': datetime.datetime(2020, 1, 28, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 26, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 1182.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fbfd'),
#  'approve_percent': 42.0,
#  'disapprove_percent': 54.0,
#  'end_date': datetime.datetime(2020, 1, 28, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 26, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fbfe'),
#  'approve_percent': 43.0,
#  'disapprove_percent': 55.0,
#  'end_date': datetime.datetime(2020, 1, 28, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 26, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 842.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fbff'),
#  'approve_percent': 41.0,
#  'disapprove_percent': 54.0,
#  'end_date': datetime.datetime(2020, 1, 27, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 25, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fc00'),
#  'approve_percent': 42.0,
#  'disapprove_percent': 56.0,
#  'end_date': datetime.datetime(2020, 1, 27, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 25, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 729.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fc03'),
#  'approve_percent': 43.0,
#  'disapprove_percent': 51.0,
#  'end_date': datetime.datetime(2020, 1, 26, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 24, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fc04'),
#  'approve_percent': 45.0,
#  'disapprove_percent': 53.0,
#  'end_date': datetime.datetime(2020, 1, 26, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 24, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 719.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fc09'),
#  'approve_percent': 39.0,
#  'disapprove_percent': 54.0,
#  'end_date': datetime.datetime(2020, 1, 24, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 23, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fc0a'),
#  'approve_percent': 45.0,
#  'disapprove_percent': 54.0,
#  'end_date': datetime.datetime(2020, 1, 24, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 23, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 797.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fc0c'),
#  'approve_percent': 43.0,
#  'disapprove_percent': 50.0,
#  'end_date': datetime.datetime(2020, 1, 24, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 22, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fc0d'),
#  'approve_percent': 46.0,
#  'disapprove_percent': 52.0,
#  'end_date': datetime.datetime(2020, 1, 24, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 22, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 731.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fc0e'),
#  'approve_percent': 45.0,
#  'disapprove_percent': 48.0,
#  'end_date': datetime.datetime(2020, 1, 23, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 21, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fc0f'),
#  'approve_percent': 48.0,
#  'disapprove_percent': 50.0,
#  'end_date': datetime.datetime(2020, 1, 23, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 21, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 729.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fc16'),
#  'approve_percent': 41.0,
#  'disapprove_percent': 48.0,
#  'end_date': datetime.datetime(2020, 1, 22, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 21, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1619.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fc1b'),
#  'approve_percent': 39.0,
#  'disapprove_percent': 54.0,
#  'end_date': datetime.datetime(2020, 1, 21, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 20, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fc1c'),
#  'approve_percent': 44.0,
#  'disapprove_percent': 54.0,
#  'end_date': datetime.datetime(2020, 1, 21, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 20, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 777.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fc1d'),
#  'approve_percent': 41.0,
#  'disapprove_percent': 50.0,
#  'end_date': datetime.datetime(2020, 1, 21, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 19, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1500.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fc1e'),
#  'approve_percent': 47.0,
#  'disapprove_percent': 51.0,
#  'end_date': datetime.datetime(2020, 1, 21, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 19, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 1176.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fc20'),
#  'approve_percent': 45.0,
#  'disapprove_percent': 48.0,
#  'end_date': datetime.datetime(2020, 1, 21, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 19, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fc21'),
#  'approve_percent': 47.0,
#  'disapprove_percent': 51.0,
#  'end_date': datetime.datetime(2020, 1, 21, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 19, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 742.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fc22'),
#  'approve_percent': 43.0,
#  'disapprove_percent': 52.0,
#  'end_date': datetime.datetime(2020, 1, 21, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 18, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fc23'),
#  'approve_percent': 45.0,
#  'disapprove_percent': 53.0,
#  'end_date': datetime.datetime(2020, 1, 21, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 18, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 734.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fc2d'),
#  'approve_percent': 41.0,
#  'disapprove_percent': 53.0,
#  'end_date': datetime.datetime(2020, 1, 19, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 17, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fc2e'),
#  'approve_percent': 44.0,
#  'disapprove_percent': 54.0,
#  'end_date': datetime.datetime(2020, 1, 19, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 17, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 746.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fc33'),
#  'approve_percent': 44.0,
#  'disapprove_percent': 49.0,
#  'end_date': datetime.datetime(2020, 1, 18, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 16, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fc34'),
#  'approve_percent': 47.0,
#  'disapprove_percent': 51.0,
#  'end_date': datetime.datetime(2020, 1, 18, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 16, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 722.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fc36'),
#  'approve_percent': 40.0,
#  'disapprove_percent': 53.0,
#  'end_date': datetime.datetime(2020, 1, 17, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 15, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fc37'),
#  'approve_percent': 43.0,
#  'disapprove_percent': 56.0,
#  'end_date': datetime.datetime(2020, 1, 17, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 15, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 731.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fc3b'),
#  'approve_percent': 40.0,
#  'disapprove_percent': 52.0,
#  'end_date': datetime.datetime(2020, 1, 16, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 14, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fc3c'),
#  'approve_percent': 42.0,
#  'disapprove_percent': 56.0,
#  'end_date': datetime.datetime(2020, 1, 16, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 14, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 743.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fc3d'),
#  'approve_percent': 39.0,
#  'disapprove_percent': 52.0,
#  'end_date': datetime.datetime(2020, 1, 15, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 13, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fc3e'),
#  'approve_percent': 43.0,
#  'disapprove_percent': 54.0,
#  'end_date': datetime.datetime(2020, 1, 15, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 13, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 719.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fc45'),
#  'approve_percent': 40.0,
#  'disapprove_percent': 53.0,
#  'end_date': datetime.datetime(2020, 1, 14, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 12, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fc46'),
#  'approve_percent': 44.0,
#  'disapprove_percent': 54.0,
#  'end_date': datetime.datetime(2020, 1, 14, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 12, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 792.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fc48'),
#  'approve_percent': 44.0,
#  'disapprove_percent': 48.0,
#  'end_date': datetime.datetime(2020, 1, 14, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 11, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1500.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1464fc49'),
#  'approve_percent': 46.0,
#  'disapprove_percent': 50.0,
#  'end_date': datetime.datetime(2020, 1, 14, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2020, 1, 11, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
# ...
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2017, 4, 2, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 1331.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab14651491'),
#  'approve_percent': 41.0,
#  'disapprove_percent': 47.0,
#  'end_date': datetime.datetime(2017, 3, 28, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2017, 3, 26, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1500.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab14651492'),
#  'approve_percent': 45.0,
#  'disapprove_percent': 50.0,
#  'end_date': datetime.datetime(2017, 3, 28, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2017, 3, 26, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 1271.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab146514be'),
#  'approve_percent': 41.0,
#  'disapprove_percent': 46.0,
#  'end_date': datetime.datetime(2017, 3, 21, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2017, 3, 19, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1500.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab146514bf'),
#  'approve_percent': 44.0,
#  'disapprove_percent': 49.0,
#  'end_date': datetime.datetime(2017, 3, 21, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2017, 3, 19, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 1296.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab146514e7'),
#  'approve_percent': 44.0,
#  'disapprove_percent': 49.0,
#  'end_date': datetime.datetime(2017, 3, 14, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2017, 3, 13, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 1320.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab146514e8'),
#  'approve_percent': 41.0,
#  'disapprove_percent': 49.0,
#  'end_date': datetime.datetime(2017, 3, 14, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2017, 3, 13, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1500.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab14651512'),
#  'approve_percent': 42.0,
#  'disapprove_percent': 49.0,
#  'end_date': datetime.datetime(2017, 3, 7, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2017, 3, 6, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1500.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab14651513'),
#  'approve_percent': 44.0,
#  'disapprove_percent': 50.0,
#  'end_date': datetime.datetime(2017, 3, 7, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2017, 3, 6, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 1359.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1465153e'),
#  'approve_percent': 41.0,
#  'disapprove_percent': 50.0,
#  'end_date': datetime.datetime(2017, 3, 1, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2017, 2, 25, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1500.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1465153f'),
#  'approve_percent': 45.0,
#  'disapprove_percent': 51.0,
#  'end_date': datetime.datetime(2017, 3, 1, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2017, 2, 25, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 1251.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab14651565'),
#  'approve_percent': 43.0,
#  'disapprove_percent': 46.0,
#  'end_date': datetime.datetime(2017, 2, 22, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2017, 2, 18, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1500.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab14651566'),
#  'approve_percent': 48.0,
#  'disapprove_percent': 48.0,
#  'end_date': datetime.datetime(2017, 2, 22, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2017, 2, 18, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 1198.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab14651583'),
#  'approve_percent': 41.0,
#  'disapprove_percent': 47.0,
#  'end_date': datetime.datetime(2017, 2, 18, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2017, 2, 17, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1000.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab14651599'),
#  'approve_percent': 43.0,
#  'disapprove_percent': 47.0,
#  'end_date': datetime.datetime(2017, 2, 14, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2017, 2, 12, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1500.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab1465159a'),
#  'approve_percent': 46.0,
#  'disapprove_percent': 49.0,
#  'end_date': datetime.datetime(2017, 2, 14, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2017, 2, 12, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 1100.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab146515c3'),
#  'approve_percent': 41.0,
#  'disapprove_percent': 48.0,
#  'end_date': datetime.datetime(2017, 2, 7, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2017, 2, 5, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1500.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab146515c4'),
#  'approve_percent': 44.0,
#  'disapprove_percent': 49.0,
#  'end_date': datetime.datetime(2017, 2, 7, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2017, 2, 5, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 1315.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab146515f4'),
#  'approve_percent': 43.0,
#  'disapprove_percent': 44.0,
#  'end_date': datetime.datetime(2017, 1, 31, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2017, 1, 28, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1500.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab146515f5'),
#  'approve_percent': 47.0,
#  'disapprove_percent': 45.0,
#  'end_date': datetime.datetime(2017, 1, 31, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2017, 1, 28, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 1278.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab14651615'),
#  'approve_percent': 41.0,
#  'disapprove_percent': 35.0,
#  'end_date': datetime.datetime(2017, 1, 25, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2017, 1, 23, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 2692.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab14651616'),
#  'approve_percent': 43.0,
#  'disapprove_percent': 39.0,
#  'end_date': datetime.datetime(2017, 1, 25, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2017, 1, 23, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Registered Voters',
#  'survey_sample': 2312.0,
#  'undecided_percent': nan}
# {'_id': ObjectId('5e67092800adebab14651635'),
#  'approve_percent': 41.0,
#  'disapprove_percent': 35.0,
#  'end_date': datetime.datetime(2017, 1, 25, 0, 0),
#  'margin_of_error': 2.3,
#  'start_date': datetime.datetime(2017, 1, 23, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 2692.0,
#  'undecided_percent': 24.0}
# {'_id': ObjectId('5e67092800adebab14651636'),
#  'approve_percent': 12.0,
#  'disapprove_percent': 68.0,
#  'end_date': datetime.datetime(2017, 1, 25, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2017, 1, 23, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults (Democrats)',
#  'survey_sample': 1025.0,
#  'undecided_percent': 20.0}
# {'_id': ObjectId('5e67092800adebab14651637'),
#  'approve_percent': 81.0,
#  'disapprove_percent': 9.0,
#  'end_date': datetime.datetime(2017, 1, 25, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2017, 1, 23, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults (Republicans)',
#  'survey_sample': 625.0,
#  'undecided_percent': 11.0}
# {'_id': ObjectId('5e67092800adebab14651638'),
#  'approve_percent': 36.0,
#  'disapprove_percent': 28.0,
#  'end_date': datetime.datetime(2017, 1, 25, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2017, 1, 23, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults (Independents)',
#  'survey_sample': 1042.0,
#  'undecided_percent': 35.0}
# {'_id': ObjectId('5e67092800adebab1465164c'),
#  'approve_percent': 43.0,
#  'disapprove_percent': 44.0,
#  'end_date': datetime.datetime(2017, 1, 31, 0, 0),
#  'margin_of_error': 3.1,
#  'start_date': datetime.datetime(2017, 1, 28, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1500.0,
#  'undecided_percent': 14.0}
# {'_id': ObjectId('5e67092800adebab1465164d'),
#  'approve_percent': 13.0,
#  'disapprove_percent': 81.0,
#  'end_date': datetime.datetime(2017, 1, 31, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2017, 1, 28, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults (Democrats)',
#  'survey_sample': 588.0,
#  'undecided_percent': 5.0}
# {'_id': ObjectId('5e67092800adebab1465164e'),
#  'approve_percent': 83.0,
#  'disapprove_percent': 11.0,
#  'end_date': datetime.datetime(2017, 1, 31, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2017, 1, 28, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults (Republicans)',
#  'survey_sample': 366.0,
#  'undecided_percent': 6.0}
# {'_id': ObjectId('5e67092800adebab1465164f'),
#  'approve_percent': 40.0,
#  'disapprove_percent': 34.0,
#  'end_date': datetime.datetime(2017, 1, 31, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2017, 1, 28, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults (Independents)',
#  'survey_sample': 546.0,
#  'undecided_percent': 26.0}
# {'_id': ObjectId('5e67092800adebab14651671'),
#  'approve_percent': 41.0,
#  'disapprove_percent': 48.0,
#  'end_date': datetime.datetime(2017, 2, 7, 0, 0),
#  'margin_of_error': 3.2,
#  'start_date': datetime.datetime(2017, 2, 5, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1500.0,
#  'undecided_percent': 11.0}
# {'_id': ObjectId('5e67092800adebab14651672'),
#  'approve_percent': 13.0,
#  'disapprove_percent': 83.0,
#  'end_date': datetime.datetime(2017, 2, 7, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2017, 2, 5, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults (Democrats)',
#  'survey_sample': 553.0,
#  'undecided_percent': 4.0}
# {'_id': ObjectId('5e67092800adebab14651673'),
#  'approve_percent': 83.0,
#  'disapprove_percent': 13.0,
#  'end_date': datetime.datetime(2017, 2, 7, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2017, 2, 5, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults (Republicans)',
#  'survey_sample': 376.0,
#  'undecided_percent': 4.0}
# {'_id': ObjectId('5e67092800adebab14651674'),
#  'approve_percent': 36.0,
#  'disapprove_percent': 43.0,
#  'end_date': datetime.datetime(2017, 2, 7, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2017, 2, 5, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults (Independents)',
#  'survey_sample': 571.0,
#  'undecided_percent': 20.0}
# {'_id': ObjectId('5e67092800adebab1465168d'),
#  'approve_percent': 43.0,
#  'disapprove_percent': 47.0,
#  'end_date': datetime.datetime(2017, 2, 14, 0, 0),
#  'margin_of_error': 3.1,
#  'start_date': datetime.datetime(2017, 2, 12, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1500.0,
#  'undecided_percent': 10.0}
# {'_id': ObjectId('5e67092800adebab1465168e'),
#  'approve_percent': 14.0,
#  'disapprove_percent': 79.0,
#  'end_date': datetime.datetime(2017, 2, 14, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2017, 2, 12, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults (Democrats)',
#  'survey_sample': 595.0,
#  'undecided_percent': 8.0}
# {'_id': ObjectId('5e67092800adebab1465168f'),
#  'approve_percent': 86.0,
#  'disapprove_percent': 11.0,
#  'end_date': datetime.datetime(2017, 2, 14, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2017, 2, 12, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults (Republicans)',
#  'survey_sample': 333.0,
#  'undecided_percent': 2.0}
# {'_id': ObjectId('5e67092800adebab14651690'),
#  'approve_percent': 39.0,
#  'disapprove_percent': 43.0,
#  'end_date': datetime.datetime(2017, 2, 14, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2017, 2, 12, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults (Independents)',
#  'survey_sample': 572.0,
#  'undecided_percent': 18.0}
# {'_id': ObjectId('5e67092800adebab146516b2'),
#  'approve_percent': 43.0,
#  'disapprove_percent': 46.0,
#  'end_date': datetime.datetime(2017, 2, 22, 0, 0),
#  'margin_of_error': 3.0,
#  'start_date': datetime.datetime(2017, 2, 18, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults',
#  'survey_sample': 1500.0,
#  'undecided_percent': 11.0}
# {'_id': ObjectId('5e67092800adebab146516b3'),
#  'approve_percent': 18.0,
#  'disapprove_percent': 78.0,
#  'end_date': datetime.datetime(2017, 2, 22, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2017, 2, 18, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults (Democrats)',
#  'survey_sample': 562.0,
#  'undecided_percent': 5.0}
# {'_id': ObjectId('5e67092800adebab146516b4'),
#  'approve_percent': 82.0,
#  'disapprove_percent': 13.0,
#  'end_date': datetime.datetime(2017, 2, 22, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2017, 2, 18, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults (Republicans)',
#  'survey_sample': 344.0,
#  'undecided_percent': 4.0}
# {'_id': ObjectId('5e67092800adebab146516b5'),
#  'approve_percent': 39.0,
#  'disapprove_percent': 41.0,
#  'end_date': datetime.datetime(2017, 2, 22, 0, 0),
#  'margin_of_error': nan,
#  'start_date': datetime.datetime(2017, 2, 18, 0, 0),
#  'survey_method': 'Online',
#  'survey_organization': 'YouGov',
#  'survey_population': 'Adults (Independents)',
#  'survey_sample': 594.0,
#  'undecided_percent': 20.0}
